# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Jan 21 14:17:09 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0              23W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import BertTokenizer, BertModel, TFBertModel, AdamW
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay,  roc_auc_score, precision_score, recall_score
import torch.nn as nn
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import ModelCheckpoint
from keras import metrics
import gc

# %% [markdown]
# # Understanding BERT
#
# This is just to show and understand the inner working of BERT transformer but won't be used as model for our data as BERT is already pre-trained and would be a waste to not take advantage of it

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %%
class SimpleSelfAttention(torch.nn.Module):
    def __init__(self, embed_size):
        super(SimpleSelfAttention, self).__init__()
        self.embed_size = embed_size

        self.query_projection = nn.Linear(embed_size, embed_size)
        self.key_projection = nn.Linear(embed_size, embed_size)
        self.value_projection = nn.Linear(embed_size, embed_size)

        self.linear = nn.Linear(embed_size, embed_size)
        self.relu = nn.ReLU()

        self.layer_norm1 = nn.LayerNorm(embed_size)
        self.layer_norm2 = nn.LayerNorm(embed_size)

    def forward(self, x):
        # Project the input to obtain queries, keys, and values
        queries = self.query_projection(x)
        keys = self.key_projection(x)
        values = self.value_projection(x)

        # Compute scaled dot-product attention
        attention_scores = torch.matmul(queries, keys.transpose(-2, -1))
        attention_scores = attention_scores / np.sqrt(self.embed_size)
        attention_weights = F.softmax(attention_scores, dim=-1)

        # Apply attention to values
        output = torch.matmul(attention_weights, values)

        # Add & Norm Layer
        output = self.layer_norm1(x + output)

        # Additional feedforward layer with ReLU activation
        output = self.linear(self.relu(self.linear(output)))

        # Add & Norm Layer
        output = self.layer_norm2(x + output)

        return output

class SimpleSelfAttentionClassifier(torch.nn.Module):
    def __init__(self, embed_size, num_classes):
        super(SimpleSelfAttentionClassifier, self).__init__()
        self.self_attention = SimpleSelfAttention(embed_size)
        self.classification = nn.Linear(embed_size, num_classes)

    def forward(self, x):
        # Apply self-attention
        attention_output = self.self_attention(x)

        # Global average pooling to get a fixed-size representation
        pooled_output = attention_output.mean(dim=1)

        # Classification layer
        logits = self.classification(pooled_output)
        return logits

# %%
embed_size = 64 #each token is a 64-d vector

# Create an instance of the model
attention_model = SimpleSelfAttention(embed_size)

# Example input
batch_size = 16 #during one iteration, 16 training examples simultaneously
sequence_length = 10
input_data = torch.randn(batch_size, sequence_length, embed_size)

# Forward pass through the attention model
output = attention_model(input_data)

print("Input shape:", input_data.shape)
print("Output shape:", output.shape)
# Out:
# Input shape: torch.Size([16, 10, 64])
# Output shape: torch.Size([16, 10, 64])

# %% [markdown]
# # Load the data
# To gain time, the data is already processed and splitted in the Data_Exploration_Processing notebook

# %%
y_train = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/y_train.tf', 'rb').read(), out_type=tf.float32)
y_val = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/y_val.tf', 'rb').read(), out_type=tf.float32)
y_test = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/y_test.tf', 'rb').read(), out_type=tf.float32)

train_claim_input_ids = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/train_claim_input_ids.tf', 'rb').read(), out_type=tf.int32)
train_claim_attention_mask = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/train_claim_attention_mask.tf', 'rb').read(), out_type=tf.int32)
train_ets_input_ids = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/train_ets_input_ids.tf', 'rb').read(), out_type=tf.int32)
train_ets_attention_mask = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/train_ets_attention_mask.tf', 'rb').read(), out_type=tf.int32)

val_claim_input_ids = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/val_claim_input_ids.tf', 'rb').read(), out_type=tf.int32)
val_claim_attention_mask = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/val_claim_attention_mask.tf', 'rb').read(), out_type=tf.int32)
val_ets_input_ids = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/val_ets_input_ids.tf', 'rb').read(), out_type=tf.int32)
val_ets_attention_mask = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/val_ets_attention_mask.tf', 'rb').read(), out_type=tf.int32)

test_claim_input_ids = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/test_claim_input_ids.tf', 'rb').read(), out_type=tf.int32)
test_claim_attention_mask = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/test_claim_attention_mask.tf', 'rb').read(), out_type=tf.int32)
test_ets_input_ids = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/test_ets_input_ids.tf', 'rb').read(), out_type=tf.int32)
test_ets_attention_mask = tf.io.parse_tensor(open('/content/drive/MyDrive/Colab Notebooks/TB/splitdataset/test_ets_attention_mask.tf', 'rb').read(), out_type=tf.int32)

# %%
print(f'Shape and datatype of Claim Input IDs:\n{train_claim_input_ids.shape}\n{type(train_claim_input_ids)}\n')
print(f'Shape and datatype of Claim Attention Mask:\n{train_claim_attention_mask.shape}\n{type(train_claim_attention_mask)}\n')
# Out:
# Shape and datatype of Claim Input IDs:
# (6219, 512)
# <class 'tensorflow.python.framework.ops.EagerTensor'>
#
# Shape and datatype of Claim Attention Mask:
# (6219, 512)
# <class 'tensorflow.python.framework.ops.EagerTensor'>

# %% [markdown]
# # Building the BERT Models

# %% [markdown]
# ## SimpleBERTClassifer (one input, Claims or ETS)

# %%
class SimpleBertClassifier(tf.keras.Model):
    def __init__(self, num_labels, max_length=128):
        super(SimpleBertClassifier, self).__init__()

        # BERT model layers
        self.bert_model = TFBertModel.from_pretrained('bert-base-uncased')

        # Input layers
        self.input_ids = Input(shape=(max_length, ), dtype=tf.int32, name="input_ids")
        self.attention_mask = Input(shape=(max_length, ), dtype=tf.int32, name="attention_mask")

        # Dense layers for classification
        self.dense1 = Dense(128, activation='relu')
        self.output_layer = Dense(num_labels, activation='sigmoid')

    def call(self, inputs, training=False):
        # Extract inputs
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']

        # BERT forward pass
        print(f"Input IDs shape: {input_ids.shape}")
        print(f"Attention Mask shape: {attention_mask.shape}")

        bert_outputs = self.bert_model(input_ids, attention_mask=attention_mask)

        print(f"Bert Outputs keys: {bert_outputs.keys()}")
        pooled_output = bert_outputs.pooler_output

        # Dense layers for classification
        print(f"Pooled Output shape: {pooled_output.shape}")
        dense1_output = self.dense1(pooled_output)
        output = self.output_layer(dense1_output)

        print(f"Output shape: {output.shape}")

        return output

# %%
# Dummy data for building the model
dummy_data = {
    'input_ids': tf.ones((1, 512), dtype=tf.int32),
    'attention_mask': tf.ones((1, 512), dtype=tf.int32)
}

# %% [markdown]
# ### Model with claims only

# %%
model_claim = SimpleBertClassifier(num_labels=1, max_length=512)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
model_claim.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5),
              loss='binary_crossentropy',
              metrics=['accuracy',
                       metrics.Precision(name='precision'),
                       metrics.Recall(name='recall'),
                       metrics.AUC(name='auc'),
                       metrics.FalsePositives(name='false_positives'),
                       metrics.FalseNegatives(name='false_negatives'),
                       metrics.TrueNegatives(name='true_negatives'),
                       metrics.F1Score(name='f1_score', average='micro')
                       ])

# %%
_ = model_claim(dummy_data)
model_claim.summary()
# Out:
# Input IDs shape: (1, 512)
# Attention Mask shape: (1, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (1, 768)
# Output shape: (1, 1)
# Model: "simple_bert_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tf_bert_model_1 (TFBertMod  multiple                  109482240
#  el)
#
#  dense_2 (Dense)             multiple                  98432
#
#  dense_3 (Dense)             multiple                  129
#
# =================================================================
# Total params: 109580801 (418.02 MB)
# Trainable params: 109580801 (418.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Model with ETS only

# %%
model_ets = SimpleBertClassifier(num_labels=1, max_length=512)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
model_ets.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5),
              loss='binary_crossentropy',
              metrics=['accuracy',
                       metrics.Precision(name='precision'),
                       metrics.Recall(name='recall'),
                       metrics.AUC(name='auc'),
                       metrics.FalsePositives(name='false_positives'),
                       metrics.FalseNegatives(name='false_negatives'),
                       metrics.TrueNegatives(name='true_negatives'),
                       metrics.F1Score(name='f1_score', average='micro')])

# %%
_ = model_ets(dummy_data)
model_ets.summary()
# Out:
# Input IDs shape: (1, 512)
# Attention Mask shape: (1, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (1, 768)
# Output shape: (1, 1)
# Model: "simple_bert_classifier_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tf_bert_model_3 (TFBertMod  multiple                  109482240
#  el)
#
#  dense_6 (Dense)             multiple                  98432
#
#  dense_7 (Dense)             multiple                  129
#
# =================================================================
# Total params: 109580801 (418.02 MB)
# Trainable params: 109580801 (418.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## DoubleBERTClassifer (two inputs, Claim and ETS)
#
# This model is able to be trained with both Claims and ETS or only with Claims. This is because it is able to predict the label of a claim without any ETS inputs as, when delivered, users will only inputs claims. Thanks to this, the model should also be benefiting from the ETS data when a user use it !

# %%
class DoubleBertClassifier(tf.keras.Model):
    def __init__(self, num_labels, max_length=128, freeze_bert=False):
        super(DoubleBertClassifier, self).__init__()

        # BERT model layers
        self.bert_model = TFBertModel.from_pretrained('bert-base-uncased')
        self.freeze_bert = freeze_bert

        if self.freeze_bert:
            self.bert_model.trainable = False

        # Input layers for claim
        self.claim_input_ids = Input(shape=(max_length, ), dtype=tf.int32, name="claim_input_ids")
        self.claim_attention_mask = Input(shape=(max_length, ), dtype=tf.int32, name="claim_attention_mask")

        # Input layers for ETS
        self.ets_input_ids = Input(shape=(max_length, ), dtype=tf.int32, name="ets_input_ids")
        self.ets_attention_mask = Input(shape=(max_length, ), dtype=tf.int32, name="ets_attention_mask")

        # Dense layers for classification
        self.dense1 = Dense(128, activation='relu')
        self.output_layer = Dense(num_labels, activation='sigmoid')

    def call(self, inputs, training=False):
        # Extract inputs for claim
        claim_input_ids = inputs['claim_input_ids'][:,:115]
        claim_attention_mask = inputs['claim_attention_mask'][:,:115]

        # Extract inputs for ETS
        ets_input_ids = inputs['ets_input_ids'][:,:397]
        ets_attention_mask = inputs['ets_attention_mask'][:,:397]

        print("Claim Input Shape: ", claim_input_ids.shape)
        print("Claim Attention Mask Shape: ", claim_attention_mask.shape)

        print("ETS Input Shape: ", claim_input_ids.shape)
        print("ETS Attention Mask Shape: ", claim_attention_mask.shape)

        if tf.reduce_sum(ets_input_ids) == 0:
          # Only claims used
          concatenated_input_ids = claim_input_ids
          concatenated_attention_mask = claim_attention_mask
        else:
          # Concate claim and ETS
          concatenated_input_ids = tf.concat([claim_input_ids, ets_input_ids], axis=1)
          concatenated_attention_mask = tf.concat([claim_attention_mask, ets_attention_mask], axis=1)

        # Print shapes for debugging
        print("Input Shape: ", concatenated_input_ids.shape)
        print("Attention Mask Shape: ", concatenated_attention_mask.shape)

        # BERT forward pass
        bert_outputs = self.bert_model(input_ids=concatenated_input_ids, attention_mask=concatenated_attention_mask)
        pooled_output = bert_outputs.pooler_output

        # Dense layers for classification
        dense1_output = self.dense1(pooled_output)
        output = self.output_layer(dense1_output)

        return output

# %% [markdown]
# Additional information :
#
#
# *   If the model is delivered and a user wants to label, they can put None as variables for the ets_input_ids and ets_attention_maks
# *   Because the maximum number of tokens across all claims is 107 and the average is 18, Claims input are trunc at 115 so that we get the most of the ETS.
# *   The "if" in the call function allows the use of placesholders for ETS inputs and attention mask so that the model can predict the label only once delivered

# %% [markdown]
# ### Non-frozen BERT-model

# %%
double_model = DoubleBertClassifier(num_labels=1, max_length=512)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
double_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5),
              loss='binary_crossentropy',
              metrics=['accuracy',
                       metrics.Precision(name='precision'),
                       metrics.Recall(name='recall'),
                       metrics.AUC(name='auc'),
                       metrics.FalsePositives(name='false_positives'),
                       metrics.FalseNegatives(name='false_negatives'),
                       metrics.TrueNegatives(name='true_negatives'),
                       metrics.F1Score(name='f1_score', average='micro')])

# %%
# Dummy data for building the model
dummy_data = {
    'claim_input_ids': tf.ones((1, 512), dtype=tf.int32),
    'claim_attention_mask': tf.ones((1, 512), dtype=tf.int32),
    'ets_input_ids': tf.ones((1, 512), dtype=tf.int32),
    'ets_attention_mask': tf.ones((1, 512), dtype=tf.int32)
}

# %%
_ = double_model(dummy_data)
double_model.summary()
# Out:
# Claim Input Shape:  (1, 115)
# Claim Attention Mask Shape:  (1, 115)
# ETS Input Shape:  (1, 115)
# ETS Attention Mask Shape:  (1, 115)
# Input Shape:  (1, 512)
# Attention Mask Shape:  (1, 512)
# Model: "double_bert_classifier_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tf_bert_model_4 (TFBertMod  multiple                  109482240
#  el)
#
#  dense_8 (Dense)             multiple                  98432
#
#  dense_9 (Dense)             multiple                  129
#
# =================================================================
# Total params: 109580801 (418.02 MB)
# Trainable params: 109580801 (418.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Frozen BERT-model

# %%
double_model_frozen = DoubleBertClassifier(num_labels=1, max_length=512, freeze_bert=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
double_model_frozen.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5),
              loss='binary_crossentropy',
              metrics=['accuracy',
                       metrics.Precision(name='precision'),
                       metrics.Recall(name='recall'),
                       metrics.AUC(name='auc'),
                       metrics.FalsePositives(name='false_positives'),
                       metrics.FalseNegatives(name='false_negatives'),
                       metrics.TrueNegatives(name='true_negatives'),
                       metrics.F1Score(name='f1_score', average='micro')])

# %%
_ = double_model_frozen(dummy_data)
double_model_frozen.summary()
# Out:
# Claim Input Shape:  (1, 115)
# Claim Attention Mask Shape:  (1, 115)
# ETS Input Shape:  (1, 115)
# ETS Attention Mask Shape:  (1, 115)
# Input Shape:  (1, 512)
# Attention Mask Shape:  (1, 512)
# Model: "double_bert_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tf_bert_model (TFBertModel  multiple                  109482240
#  )
#
#  dense (Dense)               multiple                  98432
#
#  dense_1 (Dense)             multiple                  129
#
# =================================================================
# Total params: 109580801 (418.02 MB)
# Trainable params: 98561 (385.00 KB)
# Non-trainable params: 109482240 (417.64 MB)
# _________________________________________________________________

# %% [markdown]
# # Model Checkpoints

# %%
model_checkpoint_path = '/content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/'

model_checkpoint_claim = ModelCheckpoint(
    filepath=model_checkpoint_path + 'model_claim_weights_{epoch:02d}_{val_loss:.4f}.h5',
    monitor='val_auc',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch',
    mode='max',
    verbose=1
)

model_checkpoint_ets = ModelCheckpoint(
    filepath=model_checkpoint_path + 'model_ets_weights_{epoch:02d}_{val_loss:.4f}.h5',
    monitor='val_auc',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch',
    mode='max',
    verbose=1
)

model_checkpoint_double = ModelCheckpoint(
    filepath=model_checkpoint_path + 'model_double_weights_{epoch:02d}_{val_loss:.4f}.h5',
    monitor='val_auc',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch',
    mode='max',
    verbose=1
)

model_checkpoint_double_frz = ModelCheckpoint(
    filepath=model_checkpoint_path + 'model_double_frz_weights_{epoch:02d}_{val_loss:.4f}.h5',
    monitor='val_auc',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch',
    mode='max',
    verbose=1
)

# %% [markdown]
# # Hyperparameters

# %%
subset_size = 100
batch_size = 10
num_epochs = 11

# %% [markdown]
# # SimpleBERTClassifier (Claims)

# %% [markdown]
# ### Training

# %%
history_model_claim = model_claim.fit(
    {'input_ids': train_claim_input_ids, 'attention_mask': train_claim_attention_mask},
    y_train,
    epochs=num_epochs,
    validation_data=({'input_ids': val_claim_input_ids, 'attention_mask': val_claim_attention_mask}, y_val),
    batch_size=batch_size,
    callbacks=[model_checkpoint_claim]
)
# Out:
# Epoch 1/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9855 - precision: 0.9867 - recall: 0.9827 - auc: 0.9982 - false_positives: 39.0000 - false_negatives: 51.0000 - true_negatives: 3225.0000 - f1_score: 0.6442
# Epoch 1: val_auc improved from -inf to 0.92471, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_claim_weights_01_0.5480.h5
# 622/622 [==============================] - 262s 421ms/step - loss: 0.0406 - accuracy: 0.9855 - precision: 0.9867 - recall: 0.9827 - auc: 0.9982 - false_positives: 39.0000 - false_negatives: 51.0000 - true_negatives: 3225.0000 - f1_score: 0.6442 - val_loss: 0.5480 - val_accuracy: 0.8688 - val_precision: 0.8591 - val_recall: 0.8615 - val_auc: 0.9247 - val_false_positives: 103.0000 - val_false_negatives: 101.0000 - val_true_negatives: 723.0000 - val_f1_score: 0.6384
# Epoch 2/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9921 - precision: 0.9922 - recall: 0.9912 - auc: 0.9989 - false_positives: 23.0000 - false_negatives: 26.0000 - true_negatives: 3241.0000 - f1_score: 0.6442
# Epoch 2: val_auc did not improve from 0.92471
# 622/622 [==============================] - 261s 419ms/step - loss: 0.0273 - accuracy: 0.9921 - precision: 0.9922 - recall: 0.9912 - auc: 0.9989 - false_positives: 23.0000 - false_negatives: 26.0000 - true_negatives: 3241.0000 - f1_score: 0.6442 - val_loss: 0.5962 - val_accuracy: 0.8733 - val_precision: 0.8308 - val_recall: 0.9163 - val_auc: 0.9184 - val_false_positives: 136.0000 - val_false_negatives: 61.0000 - val_true_negatives: 690.0000 - val_f1_score: 0.6384
# Epoch 3/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9920 - precision: 0.9912 - recall: 0.9919 - auc: 0.9990 - false_positives: 26.0000 - false_negatives: 24.0000 - true_negatives: 3238.0000 - f1_score: 0.6442
# Epoch 3: val_auc did not improve from 0.92471
# 622/622 [==============================] - 261s 419ms/step - loss: 0.0255 - accuracy: 0.9920 - precision: 0.9912 - recall: 0.9919 - auc: 0.9990 - false_positives: 26.0000 - false_negatives: 24.0000 - true_negatives: 3238.0000 - f1_score: 0.6442 - val_loss: 0.6370 - val_accuracy: 0.8759 - val_precision: 0.8545 - val_recall: 0.8861 - val_auc: 0.9168 - val_false_positives: 110.0000 - val_false_negatives: 83.0000 - val_true_negatives: 716.0000 - val_f1_score: 0.6384
# Epoch 4/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9926 - precision: 0.9916 - recall: 0.9929 - auc: 0.9992 - false_positives: 25.0000 - false_negatives: 21.0000 - true_negatives: 3239.0000 - f1_score: 0.6442
# Epoch 4: val_auc did not improve from 0.92471
# 622/622 [==============================] - 261s 419ms/step - loss: 0.0233 - accuracy: 0.9926 - precision: 0.9916 - recall: 0.9929 - auc: 0.9992 - false_positives: 25.0000 - false_negatives: 21.0000 - true_negatives: 3239.0000 - f1_score: 0.6442 - val_loss: 0.6263 - val_accuracy: 0.8566 - val_precision: 0.8504 - val_recall: 0.8422 - val_auc: 0.9185 - val_false_positives: 108.0000 - val_false_negatives: 115.0000 - val_true_negatives: 718.0000 - val_f1_score: 0.6384
# Epoch 5/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9939 - precision: 0.9939 - recall: 0.9932 - auc: 0.9996 - false_positives: 18.0000 - false_negatives: 20.0000 - true_negatives: 3246.0000 - f1_score: 0.6442
# Epoch 5: val_auc did not improve from 0.92471
# 622/622 [==============================] - 261s 419ms/step - loss: 0.0202 - accuracy: 0.9939 - precision: 0.9939 - recall: 0.9932 - auc: 0.9996 - false_positives: 18.0000 - false_negatives: 20.0000 - true_negatives: 3246.0000 - f1_score: 0.6442 - val_loss: 0.6015 - val_accuracy: 0.8746 - val_precision: 0.8761 - val_recall: 0.8532 - val_auc: 0.9240 - val_false_positives: 88.0000 - val_false_negatives: 107.0000 - val_true_negatives: 738.0000 - val_f1_score: 0.6384
# Epoch 6/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9945 - precision: 0.9942 - recall: 0.9942 - auc: 0.9997 - false_positives: 17.0000 - false_negatives: 17.0000 - true_negatives: 3247.0000 - f1_score: 0.6442
# Epoch 6: val_auc did not improve from 0.92471
# 622/622 [==============================] - 261s 419ms/step - loss: 0.0171 - accuracy: 0.9945 - precision: 0.9942 - recall: 0.9942 - auc: 0.9997 - false_positives: 17.0000 - false_negatives: 17.0000 - true_negatives: 3247.0000 - f1_score: 0.6442 - val_loss: 0.6859 - val_accuracy: 0.8830 - val_precision: 0.8632 - val_recall: 0.8916 - val_auc: 0.9191 - val_false_positives: 103.0000 - val_false_negatives: 79.0000 - val_true_negatives: 723.0000 - val_f1_score: 0.6384
# Epoch 7/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9966 - precision: 0.9963 - recall: 0.9966 - auc: 0.9994 - false_positives: 11.0000 - false_negatives: 10.0000 - true_negatives: 3253.0000 - f1_score: 0.6442
# Epoch 7: val_auc did not improve from 0.92471
# 622/622 [==============================] - 261s 419ms/step - loss: 0.0123 - accuracy: 0.9966 - precision: 0.9963 - recall: 0.9966 - auc: 0.9994 - false_positives: 11.0000 - false_negatives: 10.0000 - true_negatives: 3253.0000 - f1_score: 0.6442 - val_loss: 0.6695 - val_accuracy: 0.8714 - val_precision: 0.8458 - val_recall: 0.8875 - val_auc: 0.9161 - val_false_positives: 118.0000 - val_false_negatives: 82.0000 - val_true_negatives: 708.0000 - val_f1_score: 0.6384
# Epoch 8/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9966 - precision: 0.9966 - recall: 0.9963 - auc: 1.0000 - false_positives: 10.0000 - false_negatives: 11.0000 - true_negatives: 3254.0000 - f1_score: 0.6442
# Epoch 8: val_auc did not improve from 0.92471
# 622/622 [==============================] - 261s 420ms/step - loss: 0.0086 - accuracy: 0.9966 - precision: 0.9966 - recall: 0.9963 - auc: 1.0000 - false_positives: 10.0000 - false_negatives: 11.0000 - true_negatives: 3254.0000 - f1_score: 0.6442 - val_loss: 0.7961 - val_accuracy: 0.8785 - val_precision: 0.8803 - val_recall: 0.8573 - val_auc: 0.9093 - val_false_positives: 85.0000 - val_false_negatives: 104.0000 - val_true_negatives: 741.0000 - val_f1_score: 0.6384
# Epoch 9/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9960 - precision: 0.9956 - recall: 0.9959 - auc: 0.9999 - false_positives: 13.0000 - false_negatives: 12.0000 - true_negatives: 3251.0000 - f1_score: 0.6442
# Epoch 9: val_auc did not improve from 0.92471
# 622/622 [==============================] - 261s 420ms/step - loss: 0.0105 - accuracy: 0.9960 - precision: 0.9956 - recall: 0.9959 - auc: 0.9999 - false_positives: 13.0000 - false_negatives: 12.0000 - true_negatives: 3251.0000 - f1_score: 0.6442 - val_loss: 0.7937 - val_accuracy: 0.8688 - val_precision: 0.8889 - val_recall: 0.8230 - val_auc: 0.9078 - val_false_positives: 75.0000 - val_false_negatives: 129.0000 - val_true_negatives: 751.0000 - val_f1_score: 0.6384
# Epoch 10/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9965 - precision: 0.9970 - recall: 0.9956 - auc: 0.9997 - false_positives: 9.0000 - false_negatives: 13.0000 - true_negatives: 3255.0000 - f1_score: 0.6442
# Epoch 10: val_auc did not improve from 0.92471
# 622/622 [==============================] - 261s 420ms/step - loss: 0.0122 - accuracy: 0.9965 - precision: 0.9970 - recall: 0.9956 - auc: 0.9997 - false_positives: 9.0000 - false_negatives: 13.0000 - true_negatives: 3255.0000 - f1_score: 0.6442 - val_loss: 0.8694 - val_accuracy: 0.8727 - val_precision: 0.8602 - val_recall: 0.8697 - val_auc: 0.9068 - val_false_positives: 103.0000 - val_false_negatives: 95.0000 - val_true_negatives: 723.0000 - val_f1_score: 0.6384
# Epoch 11/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9961 - precision: 0.9959 - recall: 0.9959 - auc: 0.9985 - false_positives: 12.0000 - false_negatives: 12.0000 - true_negatives: 3252.0000 - f1_score: 0.6442
# Epoch 11: val_auc did not improve from 0.92471
# 622/622 [==============================] - 261s 419ms/step - loss: 0.0185 - accuracy: 0.9961 - precision: 0.9959 - recall: 0.9959 - auc: 0.9985 - false_positives: 12.0000 - false_negatives: 12.0000 - true_negatives: 3252.0000 - f1_score: 0.6442 - val_loss: 0.6643 - val_accuracy: 0.8759 - val_precision: 0.8722 - val_recall: 0.8615 - val_auc: 0.9158 - val_false_positives: 92.0000 - val_false_negatives: 101.0000 - val_true_negatives: 734.0000 - val_f1_score: 0.6384

# %%
history_model_claim.history
# Out:
# {'loss': [0.040638212114572525,
#   0.027273016050457954,
#   0.025516146793961525,
#   0.023329952731728554,
#   0.02020946331322193,
#   0.01713687740266323,
#   0.012336119078099728,
#   0.008586396463215351,
#   0.010477126576006413,
#   0.012212452478706837,
#   0.018474800512194633],
#  'accuracy': [0.9855282306671143,
#   0.9921209216117859,
#   0.9919601082801819,
#   0.9926033020019531,
#   0.9938896894454956,
#   0.9945328831672668,
#   0.9966232776641846,
#   0.9966232776641846,
#   0.9959800839424133,
#   0.9964624643325806,
#   0.9961408376693726],
#  'precision': [0.986748218536377,
#   0.9922086596488953,
#   0.9912073016166687,
#   0.9915512204170227,
#   0.9939045310020447,
#   0.9942470192909241,
#   0.9962787628173828,
#   0.9966147541999817,
#   0.9956021904945374,
#   0.9969502091407776,
#   0.9959390759468079],
#  'recall': [0.982741117477417,
#   0.9912013411521912,
#   0.9918781518936157,
#   0.992893397808075,
#   0.9932318329811096,
#   0.9942470192909241,
#   0.9966158866882324,
#   0.9962775111198425,
#   0.9959390759468079,
#   0.995600700378418,
#   0.9959390759468079],
#  'auc': [0.998163104057312,
#   0.9989187121391296,
#   0.9990176558494568,
#   0.9992008209228516,
#   0.9995837807655334,
#   0.9996727705001831,
#   0.9994271993637085,
#   0.999954879283905,
#   0.9999343156814575,
#   0.9997356534004211,
#   0.9984521269798279],
#  'false_positives': [39.0,
#   23.0,
#   26.0,
#   25.0,
#   18.0,
#   17.0,
#   11.0,
#   10.0,
#   13.0,
#   9.0,
#   12.0],
#  'false_negatives': [51.0,
#   26.0,
#   24.0,
#   21.0,
#   20.0,
#   17.0,
#   10.0,
#   11.0,
#   12.0,
#   13.0,
#   12.0],
#  'true_negatives': [3225.0,
#   3241.0,
#   3238.0,
#   3239.0,
#   3246.0,
#   3247.0,
#   3253.0,
#   3254.0,
#   3251.0,
#   3255.0,
#   3252.0],
#  'f1_score': [0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935],
#  'val_loss': [0.5479985475540161,
#   0.5961559414863586,
#   0.6369988918304443,
#   0.6262845993041992,
#   0.6015102863311768,
#   0.6859291195869446,
#   0.6694841384887695,
#   0.7960745692253113,
#   0.7936763763427734,
#   0.8694149255752563,
#   0.6643156409263611],
#  'val_accuracy': [0.8688102960586548,
#   0.8733118772506714,
#   0.8758842349052429,
#   0.8565916419029236,
#   0.8745980858802795,
#   0.882958173751831,
#   0.8713826537132263,
#   0.8784565925598145,
#   0.8688102960586548,
#   0.8726688027381897,
#   0.8758842349052429],
#  'val_precision': [0.8590971231460571,
#   0.8308457732200623,
#   0.8544973731040955,
#   0.8504155278205872,
#   0.8760563135147095,
#   0.863213837146759,
#   0.8457516431808472,
#   0.8802816867828369,
#   0.8888888955116272,
#   0.8602442145347595,
#   0.8722222447395325],
#  'val_recall': [0.8614540696144104,
#   0.916323721408844,
#   0.8861454129219055,
#   0.8422496318817139,
#   0.8532236218452454,
#   0.8916323781013489,
#   0.8875171542167664,
#   0.8573388457298279,
#   0.8230452537536621,
#   0.8696845173835754,
#   0.8614540696144104],
#  'val_auc': [0.9247078895568848,
#   0.9183913469314575,
#   0.9167637825012207,
#   0.9185474514961243,
#   0.924013614654541,
#   0.9191369414329529,
#   0.9161105155944824,
#   0.9092566967010498,
#   0.9078037142753601,
#   0.9068145155906677,
#   0.9158287048339844],
#  'val_false_positives': [103.0,
#   136.0,
#   110.0,
#   108.0,
#   88.0,
#   103.0,
#   118.0,
#   85.0,
#   75.0,
#   103.0,
#   92.0],
#  'val_false_negatives': [101.0,
#   61.0,
#   83.0,
#   115.0,
#   107.0,
#   79.0,
#   82.0,
#   104.0,
#   129.0,
#   95.0,
#   101.0],
#  'val_true_negatives': [723.0,
#   690.0,
#   716.0,
#   718.0,
#   738.0,
#   723.0,
#   708.0,
#   741.0,
#   751.0,
#   723.0,
#   734.0],
#  'val_f1_score': [0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337]}

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 15), sharex=(True, True, False), sharey='row')

# Plot training & validation loss values
axes[0, 0].plot(history_model_claim.history['loss'])
axes[0, 0].plot(history_model_claim.history['val_loss'], linestyle='dashed')
axes[0, 0].set_title('Model Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend(['Train', 'Validation'], loc='upper left')
axes[0, 0].grid(True)

# Plot training & validation accuracy values
axes[0, 1].plot(history_model_claim.history['accuracy'])
axes[0, 1].plot(history_model_claim.history['val_accuracy'], linestyle='dashed')
axes[0, 1].set_title('Model accuracy')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend(['Train', 'Validation'], loc='upper left')
axes[0, 1].grid(True)

# Plot training & validation precision values
axes[0, 2].plot(history_model_claim.history['precision'])
axes[0, 2].plot(history_model_claim.history['val_precision'], linestyle='dashed')
axes[0, 2].set_title('Model precision')
axes[0, 2].set_xlabel('Epoch')
axes[0, 2].set_ylabel('Precision')
axes[0, 2].legend(['Train', 'Validation'], loc='upper left')
axes[0, 2].grid(True)

# Plot training & validation recall values
axes[1, 0].plot(history_model_claim.history['recall'])
axes[1, 0].plot(history_model_claim.history['val_recall'], linestyle='dashed')
axes[1, 0].set_title('Model recall')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].legend(['Train', 'Validation'], loc='upper left')
axes[1, 0].grid(True)

# Plot training & validation auc values
axes[1, 1].plot(history_model_claim.history['auc'])
axes[1, 1].plot(history_model_claim.history['val_auc'], linestyle='dashed')
axes[1, 1].set_title('Model AUC')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('AUC')
axes[1, 1].legend(['Train', 'Validation'], loc='upper left')
axes[1, 1].grid(True)

# Plot training & validation f1_score values
axes[1, 2].plot(history_model_claim.history['f1_score'])
axes[1, 2].plot(history_model_claim.history['val_f1_score'], linestyle='dashed')
axes[1, 2].set_title('Model F1 Score')
axes[1, 2].set_xlabel('Epoch')
axes[1, 2].set_ylabel('F1 Score')
axes[1, 2].legend(['Train', 'Validation'], loc='upper left')
axes[1, 2].grid(True)

# Plot training & validation true negatives values
axes[2, 0].plot(history_model_claim.history['true_negatives'])
axes[2, 0].plot(history_model_claim.history['val_true_negatives'], linestyle='dashed')
axes[2, 0].set_title('Model True Negatives')
axes[2, 0].set_xlabel('Epoch')
axes[2, 0].set_ylabel('True Negatives')
axes[2, 0].legend(['Train', 'Validation'], loc='upper left')
axes[2, 0].grid(True)

# Plot training & validation false positives values
axes[2, 1].plot(history_model_claim.history['false_positives'])
axes[2, 1].plot(history_model_claim.history['val_false_positives'], linestyle='dashed')
axes[2, 1].set_title('Model False Positives')
axes[2, 1].set_xlabel('Epoch')
axes[2, 1].set_ylabel('False Positives')
axes[2, 1].legend(['Train', 'Validation'], loc='upper left')
axes[2, 1].grid(True)

# Plot training & validation false negatives values
axes[2, 2].plot(history_model_claim.history['false_negatives'])
axes[2, 2].plot(history_model_claim.history['val_false_negatives'], linestyle='dashed')
axes[2, 2].set_title('Model False Negatives')
axes[2, 2].set_xlabel('Epoch')
axes[2, 2].set_ylabel('False Negatives')
axes[2, 2].legend(['Train', 'Validation'], loc='upper left')
axes[2, 2].grid(True)

plt.suptitle('Training and Validation Metrics over 11 Epochs for SimpleBERTClassifier (Claim)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluate

# %% [markdown]
# Load the weights from the model with the smallest validation loss

# %%
model_claim.load_weights(model_checkpoint_path + 'model_claim_weights_01_0.5480.h5') #first epoch

# %%
evaluation_model_claim = model_claim.evaluate({'input_ids': test_claim_input_ids, 'attention_mask': test_claim_attention_mask},
                            y_test)

metrics_names = model_claim.metrics_names

print('Metrics for the SimpleBERTClassifier (Claim) model with the AUC validation loss')
for metric_name, metric_value in zip(metrics_names, evaluation_model_claim):
    print(f"{metric_name}: {metric_value:.4f}")
# Out:
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
# 61/61 [==============================] - 29s 382ms/step - loss: 0.5136 - accuracy: 0.8714 - precision: 0.8742 - recall: 0.8594 - auc: 0.9255 - false_positives: 117.0000 - false_negatives: 133.0000 - true_negatives: 881.0000 - f1_score: 0.6547
# Metrics for the SimpleBERTClassifier (Claim) model with the AUC validation loss
# loss: 0.5136
# accuracy: 0.8714
# precision: 0.8742
# recall: 0.8594
# auc: 0.9255
# false_positives: 117.0000
# false_negatives: 133.0000
# true_negatives: 881.0000
# f1_score: 0.6547

# %% [markdown]
# ## Prediction
#
# RESULTS :

# %%
# Using the model to make predictions on validation data
predictions_model_claim = model_claim.predict({'input_ids': test_claim_input_ids, 'attention_mask': test_claim_attention_mask})
predicted_labels = np.round(predictions_model_claim)
# Out:
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
# 61/61 [==============================] - 29s 375ms/step

# %%
print(f'Predicted labels: {predictions_model_claim}')
print(f'Rounded predicted labels: {predicted_labels}')

accuracy_model_claim = accuracy_score(y_test, predicted_labels)
print(f'Accuracy: {accuracy_model_claim:.4f}')
print()

auc_model_claim = roc_auc_score(y_test, predictions_model_claim)
print(f'AUC: {auc_model_claim:.4f}')
print()

precision_model_claim = precision_score(y_test, predicted_labels)
print(f'Precision: {precision_model_claim:.4f}')
print()

recall_model_claim = recall_score(y_test, predicted_labels)
print(f'Recall: {recall_model_claim:.4f}')
print()
# Generate a confusion matrix
conf_mat_model_claim = confusion_matrix(y_test, predicted_labels)
print('Confusion Matrix:')
print(conf_mat_model_claim)
# Out:
# Predicted labels: [[1.4877165e-03]
#  [9.9946517e-01]
#  [4.4742625e-04]
#  ...
#  [9.9901068e-01]
#  [8.1310891e-02]
#  [8.8716608e-01]]
# Rounded predicted labels: [[0.]
#  [1.]
#  [0.]
#  ...
#  [1.]
#  [0.]
#  [1.]]
# Accuracy: 0.8714
#
# AUC: 0.9379
#
# Precision: 0.8742
#
# Recall: 0.8594
#
# Confusion Matrix:
# [[881 117]
#  [133 813]]

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat_model_claim, display_labels=['FAKE', 'TRUE'])
disp.plot()
plt.show()

# %%
model_claim.save_weights("/content/drive/MyDrive/Colab Notebooks/TB/final_weights/SimpleBERTClassifierCLAIM_weights", save_format="tf")

# %%
#model_claim.save("SimpleBERTClassifier_Claim", save_format="tf")
# Out:
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)

# %%
#del model_claim
#del history_model_claim
#del evaluation_model_claim
#del predictions_model_claim

# %%
gc.collect()
# Out:
# 8960

# %% [markdown]
# # SimpleBERTClassifier (ETS)

# %% [markdown]
# ## Training
#
# RESULTS :

# %%
history_model_ets = model_ets.fit(
    {'input_ids': train_ets_input_ids, 'attention_mask': train_ets_attention_mask},
    y_train,
    epochs=num_epochs,
    validation_data=({'input_ids': val_ets_input_ids, 'attention_mask': val_ets_attention_mask}, y_val),
    batch_size=batch_size,
    callbacks=[model_checkpoint_ets]
)
# Out:
# Epoch 1/11
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
# 622/622 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.7974 - precision: 0.7932 - recall: 0.7760 - auc: 0.8189 - false_positives: 598.0000 - false_negatives: 662.0000 - true_negatives: 2666.0000 - f1_score: 0.6442Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
#
# Epoch 1: val_auc improved from -inf to 0.82789, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_ets_weights_01_0.4818.h5
# 622/622 [==============================] - 305s 428ms/step - loss: 0.5000 - accuracy: 0.7974 - precision: 0.7932 - recall: 0.7760 - auc: 0.8189 - false_positives: 598.0000 - false_negatives: 662.0000 - true_negatives: 2666.0000 - f1_score: 0.6442 - val_loss: 0.4818 - val_accuracy: 0.8122 - val_precision: 0.8031 - val_recall: 0.7942 - val_auc: 0.8279 - val_false_positives: 142.0000 - val_false_negatives: 150.0000 - val_true_negatives: 684.0000 - val_f1_score: 0.6384
# Epoch 2/11
# 622/622 [==============================] - ETA: 0s - loss: 0.4583 - accuracy: 0.8101 - precision: 0.7941 - recall: 0.8105 - auc: 0.8516 - false_positives: 621.0000 - false_negatives: 560.0000 - true_negatives: 2643.0000 - f1_score: 0.6442
# Epoch 2: val_auc improved from 0.82789 to 0.84569, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_ets_weights_02_0.4736.h5
# 622/622 [==============================] - 262s 422ms/step - loss: 0.4583 - accuracy: 0.8101 - precision: 0.7941 - recall: 0.8105 - auc: 0.8516 - false_positives: 621.0000 - false_negatives: 560.0000 - true_negatives: 2643.0000 - f1_score: 0.6442 - val_loss: 0.4736 - val_accuracy: 0.8084 - val_precision: 0.8031 - val_recall: 0.7833 - val_auc: 0.8457 - val_false_positives: 140.0000 - val_false_negatives: 158.0000 - val_true_negatives: 686.0000 - val_f1_score: 0.6384
# Epoch 3/11
# 622/622 [==============================] - ETA: 0s - loss: 0.3816 - accuracy: 0.8487 - precision: 0.8035 - recall: 0.9022 - auc: 0.8919 - false_positives: 652.0000 - false_negatives: 289.0000 - true_negatives: 2612.0000 - f1_score: 0.6442
# Epoch 3: val_auc did not improve from 0.84569
# 622/622 [==============================] - 261s 419ms/step - loss: 0.3816 - accuracy: 0.8487 - precision: 0.8035 - recall: 0.9022 - auc: 0.8919 - false_positives: 652.0000 - false_negatives: 289.0000 - true_negatives: 2612.0000 - f1_score: 0.6442 - val_loss: 0.5178 - val_accuracy: 0.7666 - val_precision: 0.6951 - val_recall: 0.8944 - val_auc: 0.8342 - val_false_positives: 286.0000 - val_false_negatives: 77.0000 - val_true_negatives: 540.0000 - val_f1_score: 0.6384
# Epoch 4/11
# 622/622 [==============================] - ETA: 0s - loss: 0.2752 - accuracy: 0.8940 - precision: 0.8347 - recall: 0.9689 - auc: 0.9368 - false_positives: 567.0000 - false_negatives: 92.0000 - true_negatives: 2697.0000 - f1_score: 0.6442
# Epoch 4: val_auc did not improve from 0.84569
# 622/622 [==============================] - 261s 419ms/step - loss: 0.2752 - accuracy: 0.8940 - precision: 0.8347 - recall: 0.9689 - auc: 0.9368 - false_positives: 567.0000 - false_negatives: 92.0000 - true_negatives: 2697.0000 - f1_score: 0.6442 - val_loss: 0.6176 - val_accuracy: 0.7859 - val_precision: 0.7225 - val_recall: 0.8820 - val_auc: 0.8051 - val_false_positives: 247.0000 - val_false_negatives: 86.0000 - val_true_negatives: 579.0000 - val_f1_score: 0.6384
# Epoch 5/11
# 622/622 [==============================] - ETA: 0s - loss: 0.2236 - accuracy: 0.9069 - precision: 0.8460 - recall: 0.9831 - auc: 0.9593 - false_positives: 529.0000 - false_negatives: 50.0000 - true_negatives: 2735.0000 - f1_score: 0.6442
# Epoch 5: val_auc did not improve from 0.84569
# 622/622 [==============================] - 261s 420ms/step - loss: 0.2236 - accuracy: 0.9069 - precision: 0.8460 - recall: 0.9831 - auc: 0.9593 - false_positives: 529.0000 - false_negatives: 50.0000 - true_negatives: 2735.0000 - f1_score: 0.6442 - val_loss: 0.6265 - val_accuracy: 0.8135 - val_precision: 0.7840 - val_recall: 0.8313 - val_auc: 0.8431 - val_false_positives: 167.0000 - val_false_negatives: 123.0000 - val_true_negatives: 659.0000 - val_f1_score: 0.6384
# Epoch 6/11
# 622/622 [==============================] - ETA: 0s - loss: 0.1830 - accuracy: 0.9164 - precision: 0.8695 - recall: 0.9695 - auc: 0.9753 - false_positives: 430.0000 - false_negatives: 90.0000 - true_negatives: 2834.0000 - f1_score: 0.6442
# Epoch 6: val_auc did not improve from 0.84569
# 622/622 [==============================] - 261s 420ms/step - loss: 0.1830 - accuracy: 0.9164 - precision: 0.8695 - recall: 0.9695 - auc: 0.9753 - false_positives: 430.0000 - false_negatives: 90.0000 - true_negatives: 2834.0000 - f1_score: 0.6442 - val_loss: 0.7617 - val_accuracy: 0.8103 - val_precision: 0.7840 - val_recall: 0.8217 - val_auc: 0.8406 - val_false_positives: 165.0000 - val_false_negatives: 130.0000 - val_true_negatives: 661.0000 - val_f1_score: 0.6384
# Epoch 7/11
# 622/622 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9259 - precision: 0.8999 - recall: 0.9496 - auc: 0.9824 - false_positives: 312.0000 - false_negatives: 149.0000 - true_negatives: 2952.0000 - f1_score: 0.6442
# Epoch 7: val_auc did not improve from 0.84569
# 622/622 [==============================] - 261s 420ms/step - loss: 0.1606 - accuracy: 0.9259 - precision: 0.8999 - recall: 0.9496 - auc: 0.9824 - false_positives: 312.0000 - false_negatives: 149.0000 - true_negatives: 2952.0000 - f1_score: 0.6442 - val_loss: 0.7690 - val_accuracy: 0.7897 - val_precision: 0.7716 - val_recall: 0.7833 - val_auc: 0.8342 - val_false_positives: 169.0000 - val_false_negatives: 158.0000 - val_true_negatives: 657.0000 - val_f1_score: 0.6384
# Epoch 8/11
# 622/622 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9379 - precision: 0.9232 - recall: 0.9482 - auc: 0.9892 - false_positives: 233.0000 - false_negatives: 153.0000 - true_negatives: 3031.0000 - f1_score: 0.6442
# Epoch 8: val_auc did not improve from 0.84569
# 622/622 [==============================] - 261s 420ms/step - loss: 0.1265 - accuracy: 0.9379 - precision: 0.9232 - recall: 0.9482 - auc: 0.9892 - false_positives: 233.0000 - false_negatives: 153.0000 - true_negatives: 3031.0000 - f1_score: 0.6442 - val_loss: 0.8887 - val_accuracy: 0.7904 - val_precision: 0.7779 - val_recall: 0.7737 - val_auc: 0.8368 - val_false_positives: 161.0000 - val_false_negatives: 165.0000 - val_true_negatives: 665.0000 - val_f1_score: 0.6384
# Epoch 9/11
# 622/622 [==============================] - ETA: 0s - loss: 0.1069 - accuracy: 0.9460 - precision: 0.9414 - recall: 0.9452 - auc: 0.9922 - false_positives: 174.0000 - false_negatives: 162.0000 - true_negatives: 3090.0000 - f1_score: 0.6442
# Epoch 9: val_auc did not improve from 0.84569
# 622/622 [==============================] - 261s 419ms/step - loss: 0.1069 - accuracy: 0.9460 - precision: 0.9414 - recall: 0.9452 - auc: 0.9922 - false_positives: 174.0000 - false_negatives: 162.0000 - true_negatives: 3090.0000 - f1_score: 0.6442 - val_loss: 1.0304 - val_accuracy: 0.7698 - val_precision: 0.7310 - val_recall: 0.8052 - val_auc: 0.8112 - val_false_positives: 216.0000 - val_false_negatives: 142.0000 - val_true_negatives: 610.0000 - val_f1_score: 0.6384
# Epoch 10/11
# 622/622 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9495 - precision: 0.9424 - recall: 0.9519 - auc: 0.9918 - false_positives: 172.0000 - false_negatives: 142.0000 - true_negatives: 3092.0000 - f1_score: 0.6442
# Epoch 10: val_auc did not improve from 0.84569
# 622/622 [==============================] - 261s 420ms/step - loss: 0.1094 - accuracy: 0.9495 - precision: 0.9424 - recall: 0.9519 - auc: 0.9918 - false_positives: 172.0000 - false_negatives: 142.0000 - true_negatives: 3092.0000 - f1_score: 0.6442 - val_loss: 0.9084 - val_accuracy: 0.7743 - val_precision: 0.7855 - val_recall: 0.7133 - val_auc: 0.8335 - val_false_positives: 142.0000 - val_false_negatives: 209.0000 - val_true_negatives: 684.0000 - val_f1_score: 0.6384
# Epoch 11/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9563 - precision: 0.9506 - recall: 0.9577 - auc: 0.9947 - false_positives: 147.0000 - false_negatives: 125.0000 - true_negatives: 3117.0000 - f1_score: 0.6442
# Epoch 11: val_auc did not improve from 0.84569
# 622/622 [==============================] - 261s 420ms/step - loss: 0.0868 - accuracy: 0.9563 - precision: 0.9506 - recall: 0.9577 - auc: 0.9947 - false_positives: 147.0000 - false_negatives: 125.0000 - true_negatives: 3117.0000 - f1_score: 0.6442 - val_loss: 1.0673 - val_accuracy: 0.7723 - val_precision: 0.7721 - val_recall: 0.7298 - val_auc: 0.8248 - val_false_positives: 157.0000 - val_false_negatives: 197.0000 - val_true_negatives: 669.0000 - val_f1_score: 0.6384

# %%
history_model_ets.history
# Out:
# {'loss': [0.4999997615814209,
#   0.458292692899704,
#   0.38163620233535767,
#   0.27521488070487976,
#   0.2235661894083023,
#   0.18304848670959473,
#   0.16057996451854706,
#   0.12653996050357819,
#   0.10685118287801743,
#   0.10935279726982117,
#   0.08682162314653397],
#  'accuracy': [0.7973950505256653,
#   0.8100981116294861,
#   0.8486894965171814,
#   0.8940343856811523,
#   0.9068982005119324,
#   0.916385293006897,
#   0.9258723258972168,
#   0.9379321336746216,
#   0.9459720253944397,
#   0.9495095610618591,
#   0.9562630653381348],
#  'precision': [0.7931511402130127,
#   0.7940981388092041,
#   0.8034960627555847,
#   0.8346938490867615,
#   0.8459522128105164,
#   0.8694992661476135,
#   0.8999358415603638,
#   0.9232289791107178,
#   0.9413549304008484,
#   0.942378580570221,
#   0.9506214261054993],
#  'recall': [0.7759729027748108,
#   0.8104906678199768,
#   0.9021996855735779,
#   0.9688663482666016,
#   0.9830795526504517,
#   0.9695431590080261,
#   0.9495769739151001,
#   0.948223352432251,
#   0.9451776742935181,
#   0.9519458413124084,
#   0.9576988220214844],
#  'auc': [0.8189083337783813,
#   0.8516055345535278,
#   0.8918508887290955,
#   0.9368243217468262,
#   0.9592962861061096,
#   0.9752638339996338,
#   0.9824296236038208,
#   0.989211916923523,
#   0.9921842217445374,
#   0.9917877912521362,
#   0.994657576084137],
#  'false_positives': [598.0,
#   621.0,
#   652.0,
#   567.0,
#   529.0,
#   430.0,
#   312.0,
#   233.0,
#   174.0,
#   172.0,
#   147.0],
#  'false_negatives': [662.0,
#   560.0,
#   289.0,
#   92.0,
#   50.0,
#   90.0,
#   149.0,
#   153.0,
#   162.0,
#   142.0,
#   125.0],
#  'true_negatives': [2666.0,
#   2643.0,
#   2612.0,
#   2697.0,
#   2735.0,
#   2834.0,
#   2952.0,
#   3031.0,
#   3090.0,
#   3092.0,
#   3117.0],
#  'f1_score': [0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935],
#  'val_loss': [0.4818001389503479,
#   0.4736400246620178,
#   0.5177701711654663,
#   0.6176113486289978,
#   0.626495897769928,
#   0.761738121509552,
#   0.7690032720565796,
#   0.8887034058570862,
#   1.0304161310195923,
#   0.9083660840988159,
#   1.0673465728759766],
#  'val_accuracy': [0.8122186660766602,
#   0.8083600997924805,
#   0.7665594816207886,
#   0.7858520746231079,
#   0.8135048151016235,
#   0.8102893829345703,
#   0.7897105813026428,
#   0.7903537154197693,
#   0.7697749137878418,
#   0.7742765545845032,
#   0.7723472714424133],
#  'val_precision': [0.8030512928962708,
#   0.803094208240509,
#   0.695095956325531,
#   0.7224718928337097,
#   0.7839586138725281,
#   0.7840313911437988,
#   0.7716216444969177,
#   0.7779310345649719,
#   0.7310087084770203,
#   0.7854984998703003,
#   0.7721335291862488],
#  'val_recall': [0.7942386865615845,
#   0.7832647562026978,
#   0.8943758606910706,
#   0.882030189037323,
#   0.8312757015228271,
#   0.8216735124588013,
#   0.7832647562026978,
#   0.7736625671386719,
#   0.8052126169204712,
#   0.7133058905601501,
#   0.7297667860984802],
#  'val_auc': [0.8278887271881104,
#   0.845685601234436,
#   0.8342093825340271,
#   0.8051271438598633,
#   0.84309983253479,
#   0.8406089544296265,
#   0.8341819643974304,
#   0.8368381261825562,
#   0.8112135529518127,
#   0.8334876298904419,
#   0.824833869934082],
#  'val_false_positives': [142.0,
#   140.0,
#   286.0,
#   247.0,
#   167.0,
#   165.0,
#   169.0,
#   161.0,
#   216.0,
#   142.0,
#   157.0],
#  'val_false_negatives': [150.0,
#   158.0,
#   77.0,
#   86.0,
#   123.0,
#   130.0,
#   158.0,
#   165.0,
#   142.0,
#   209.0,
#   197.0],
#  'val_true_negatives': [684.0,
#   686.0,
#   540.0,
#   579.0,
#   659.0,
#   661.0,
#   657.0,
#   665.0,
#   610.0,
#   684.0,
#   669.0],
#  'val_f1_score': [0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337]}

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 15), sharex=(True, True, False), sharey='row')

# Plot training & validation loss values
axes[0, 0].plot(history_model_ets.history['loss'])
axes[0, 0].plot(history_model_ets.history['val_loss'], linestyle='dashed')
axes[0, 0].set_title('Model Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend(['Train', 'Validation'], loc='upper left')
axes[0, 0].grid(True)

# Plot training & validation accuracy values
axes[0, 1].plot(history_model_ets.history['accuracy'])
axes[0, 1].plot(history_model_ets.history['val_accuracy'], linestyle='dashed')
axes[0, 1].set_title('Model accuracy')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend(['Train', 'Validation'], loc='upper left')
axes[0, 1].grid(True)

# Plot training & validation precision values
axes[0, 2].plot(history_model_ets.history['precision'])
axes[0, 2].plot(history_model_ets.history['val_precision'], linestyle='dashed')
axes[0, 2].set_title('Model precision')
axes[0, 2].set_xlabel('Epoch')
axes[0, 2].set_ylabel('Precision')
axes[0, 2].legend(['Train', 'Validation'], loc='upper left')
axes[0, 2].grid(True)

# Plot training & validation recall values
axes[1, 0].plot(history_model_ets.history['recall'])
axes[1, 0].plot(history_model_ets.history['val_recall'], linestyle='dashed')
axes[1, 0].set_title('Model recall')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].legend(['Train', 'Validation'], loc='upper left')
axes[1, 0].grid(True)

# Plot training & validation auc values
axes[1, 1].plot(history_model_ets.history['auc'])
axes[1, 1].plot(history_model_ets.history['val_auc'], linestyle='dashed')
axes[1, 1].set_title('Model AUC')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('AUC')
axes[1, 1].legend(['Train', 'Validation'], loc='upper left')
axes[1, 1].grid(True)

# Plot training & validation f1_score values
axes[1, 2].plot(history_model_ets.history['f1_score'])
axes[1, 2].plot(history_model_ets.history['val_f1_score'], linestyle='dashed')
axes[1, 2].set_title('Model F1 Score')
axes[1, 2].set_xlabel('Epoch')
axes[1, 2].set_ylabel('F1 Score')
axes[1, 2].legend(['Train', 'Validation'], loc='upper left')
axes[1, 2].grid(True)

# Plot training & validation true negatives values
axes[2, 0].plot(history_model_ets.history['true_negatives'])
axes[2, 0].plot(history_model_ets.history['val_true_negatives'], linestyle='dashed')
axes[2, 0].set_title('Model True Negatives')
axes[2, 0].set_xlabel('Epoch')
axes[2, 0].set_ylabel('True Negatives')
axes[2, 0].legend(['Train', 'Validation'], loc='upper left')
axes[2, 0].grid(True)

# Plot training & validation false positives values
axes[2, 1].plot(history_model_ets.history['false_positives'])
axes[2, 1].plot(history_model_ets.history['val_false_positives'], linestyle='dashed')
axes[2, 1].set_title('Model False Positives')
axes[2, 1].set_xlabel('Epoch')
axes[2, 1].set_ylabel('False Positives')
axes[2, 1].legend(['Train', 'Validation'], loc='upper left')
axes[2, 1].grid(True)

# Plot training & validation false negatives values
axes[2, 2].plot(history_model_ets.history['false_negatives'])
axes[2, 2].plot(history_model_ets.history['val_false_negatives'], linestyle='dashed')
axes[2, 2].set_title('Model False Negatives')
axes[2, 2].set_xlabel('Epoch')
axes[2, 2].set_ylabel('False Negatives')
axes[2, 2].legend(['Train', 'Validation'], loc='upper left')
axes[2, 2].grid(True)

plt.suptitle('Training and Validation Metrics over 11 Epochs for SimpleBERTClassifier (ETS)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluate

# %%
model_ets.load_weights(model_checkpoint_path + 'model_ets_weights_02_0.4736.h5') #second epoch

# %%
evaluation_model_ets = model_ets.evaluate({'input_ids': test_ets_input_ids, 'attention_mask': test_ets_attention_mask},
                            y_test)

metrics_names = model_ets.metrics_names

print('Metrics for the SimpleBERTClassifier (ETS) model with the lowest AUC loss')
for metric_name, metric_value in zip(metrics_names, evaluation_model_ets):
    print(f"{metric_name}: {metric_value:.4f}")
# Out:
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
# 61/61 [==============================] - 28s 382ms/step - loss: 0.4926 - accuracy: 0.7968 - precision: 0.8031 - recall: 0.7717 - auc: 0.8425 - false_positives: 179.0000 - false_negatives: 216.0000 - true_negatives: 819.0000 - f1_score: 0.6547
# Metrics for the SimpleBERTClassifier (ETS) model with the lowest AUC loss
# loss: 0.4926
# accuracy: 0.7968
# precision: 0.8031
# recall: 0.7717
# auc: 0.8425
# false_positives: 179.0000
# false_negatives: 216.0000
# true_negatives: 819.0000
# f1_score: 0.6547

# %% [markdown]
# ## Prediction
#
# RESULTS :

# %%
# Using the model to make predictions on test data
predictions_model_ets = model_ets.predict({'input_ids': test_claim_input_ids, 'attention_mask': test_claim_attention_mask})
predicted_labels = np.round(predictions_model_ets)
# Out:
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
# 61/61 [==============================] - 26s 376ms/step

# %%
print(f'Predicted labels: {predictions_model_ets}')
print(f'Rounded predicted labels: {predicted_labels}')

accuracy_model_ets = accuracy_score(y_test, predicted_labels)
print(f'Accuracy: {accuracy_model_ets:.4f}')

auc_model_ets = roc_auc_score(y_test, predictions_model_ets)
print(f'AUC: {auc_model_ets:.4f}')
print()

precision_model_ets = precision_score(y_test, predicted_labels)
print(f'Precision: {precision_model_ets:.4f}')
print()

recall_model_ets = recall_score(y_test, predicted_labels)
print(f'Recall: {recall_model_ets:.4f}')
print()

# Generate a confusion matrix
conf_mat_model_ets = confusion_matrix(y_test, predicted_labels)
print('Confusion Matrix:')
print(conf_mat_model_ets)
# Out:
# Predicted labels: [[0.3685471 ]
#  [0.20176524]
#  [0.03680644]
#  ...
#  [0.28436926]
#  [0.17923528]
#  [0.3434451 ]]
# Rounded predicted labels: [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]
# Accuracy: 0.5602
# AUC: 0.7904
#
# Precision: 0.8273
#
# Recall: 0.1216
#
# Confusion Matrix:
# [[974  24]
#  [831 115]]

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat_model_ets, display_labels=['FAKE', 'TRUE'])
disp.plot()
plt.show()

# %%
model_ets.save_weights("/content/drive/MyDrive/Colab Notebooks/TB/final_weights/SimpleBERTClassifierETS_weights", save_format="tf")

# %%
#model_ets.save("SimpleBERTClassifier_ETS", save_format="tf")
# Out:
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)
# Input IDs shape: (None, 512)
# Attention Mask shape: (None, 512)
# Bert Outputs keys: odict_keys(['last_hidden_state', 'pooler_output'])
# Pooled Output shape: (None, 768)
# Output shape: (None, 1)

# %%
#del model_ets
#del history_model_ets
#del evaluation_model_ets
#del predictions_model_ets

# %%
gc.collect()
# Out:
# 73492

# %% [markdown]
# # DoubleBERTClassifier (Claims & ETS)

# %% [markdown]
# ## Training
#
# RESULTS :

# %%
history_double_model = double_model.fit(
    {'claim_input_ids': train_claim_input_ids,
    'claim_attention_mask': train_claim_attention_mask,
    'ets_input_ids': train_ets_input_ids,
    'ets_attention_mask': train_ets_attention_mask},
    y_train,
    epochs=num_epochs,
     validation_data=({'claim_input_ids': val_claim_input_ids, 'claim_attention_mask': val_claim_attention_mask,
                       'ets_input_ids': val_ets_input_ids, 'ets_attention_mask': val_ets_attention_mask}, y_val),
    batch_size=batch_size,
    callbacks=[model_checkpoint_double]
)
# Out:
# Epoch 1/11
# Claim Input Shape:  (None, 115)
# Claim Attention Mask Shape:  (None, 115)
# ETS Input Shape:  (None, 115)
# ETS Attention Mask Shape:  (None, 115)
# Input Shape:  (None, None)
# Attention Mask Shape:  (None, None)
# Claim Input Shape:  (None, 115)
# Claim Attention Mask Shape:  (None, 115)
# ETS Input Shape:  (None, 115)
# ETS Attention Mask Shape:  (None, 115)
# Input Shape:  (None, None)
# Attention Mask Shape:  (None, None)
# 622/622 [==============================] - ETA: 0s - loss: 0.4760 - accuracy: 0.8030 - precision: 0.8150 - recall: 0.7574 - auc: 0.8454 - false_positives: 508.0000 - false_negatives: 717.0000 - true_negatives: 2756.0000 - f1_score: 0.6442Claim Input Shape:  (None, 115)
# Claim Attention Mask Shape:  (None, 115)
# ETS Input Shape:  (None, 115)
# ETS Attention Mask Shape:  (None, 115)
# Input Shape:  (None, None)
# Attention Mask Shape:  (None, None)
#
# Epoch 1: val_auc improved from -inf to 0.89421, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_double_weights_01_0.4233.h5
# 622/622 [==============================] - 305s 428ms/step - loss: 0.4760 - accuracy: 0.8030 - precision: 0.8150 - recall: 0.7574 - auc: 0.8454 - false_positives: 508.0000 - false_negatives: 717.0000 - true_negatives: 2756.0000 - f1_score: 0.6442 - val_loss: 0.4233 - val_accuracy: 0.8392 - val_precision: 0.8538 - val_recall: 0.7929 - val_auc: 0.8942 - val_false_positives: 99.0000 - val_false_negatives: 151.0000 - val_true_negatives: 727.0000 - val_f1_score: 0.6384
# Epoch 2/11
# 622/622 [==============================] - ETA: 0s - loss: 0.3481 - accuracy: 0.8611 - precision: 0.8649 - recall: 0.8386 - auc: 0.9228 - false_positives: 387.0000 - false_negatives: 477.0000 - true_negatives: 2877.0000 - f1_score: 0.6442
# Epoch 2: val_auc improved from 0.89421 to 0.92926, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_double_weights_02_0.3757.h5
# 622/622 [==============================] - 263s 422ms/step - loss: 0.3481 - accuracy: 0.8611 - precision: 0.8649 - recall: 0.8386 - auc: 0.9228 - false_positives: 387.0000 - false_negatives: 477.0000 - true_negatives: 2877.0000 - f1_score: 0.6442 - val_loss: 0.3757 - val_accuracy: 0.8572 - val_precision: 0.8358 - val_recall: 0.8656 - val_auc: 0.9293 - val_false_positives: 124.0000 - val_false_negatives: 98.0000 - val_true_negatives: 702.0000 - val_f1_score: 0.6384
# Epoch 3/11
# 622/622 [==============================] - ETA: 0s - loss: 0.1910 - accuracy: 0.9276 - precision: 0.9233 - recall: 0.9245 - auc: 0.9769 - false_positives: 227.0000 - false_negatives: 223.0000 - true_negatives: 3037.0000 - f1_score: 0.6442
# Epoch 3: val_auc improved from 0.92926 to 0.93778, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_double_weights_03_0.3810.h5
# 622/622 [==============================] - 263s 422ms/step - loss: 0.1910 - accuracy: 0.9276 - precision: 0.9233 - recall: 0.9245 - auc: 0.9769 - false_positives: 227.0000 - false_negatives: 223.0000 - true_negatives: 3037.0000 - f1_score: 0.6442 - val_loss: 0.3810 - val_accuracy: 0.8605 - val_precision: 0.8040 - val_recall: 0.9287 - val_auc: 0.9378 - val_false_positives: 165.0000 - val_false_negatives: 52.0000 - val_true_negatives: 661.0000 - val_f1_score: 0.6384
# Epoch 4/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0710 - accuracy: 0.9760 - precision: 0.9733 - recall: 0.9763 - auc: 0.9963 - false_positives: 79.0000 - false_negatives: 70.0000 - true_negatives: 3185.0000 - f1_score: 0.6442
# Epoch 4: val_auc did not improve from 0.93778
# 622/622 [==============================] - 261s 420ms/step - loss: 0.0710 - accuracy: 0.9760 - precision: 0.9733 - recall: 0.9763 - auc: 0.9963 - false_positives: 79.0000 - false_negatives: 70.0000 - true_negatives: 3185.0000 - f1_score: 0.6442 - val_loss: 0.4777 - val_accuracy: 0.8875 - val_precision: 0.8764 - val_recall: 0.8848 - val_auc: 0.9342 - val_false_positives: 91.0000 - val_false_negatives: 84.0000 - val_true_negatives: 735.0000 - val_f1_score: 0.6384
# Epoch 5/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9886 - precision: 0.9862 - recall: 0.9898 - auc: 0.9990 - false_positives: 41.0000 - false_negatives: 30.0000 - true_negatives: 3223.0000 - f1_score: 0.6442
# Epoch 5: val_auc did not improve from 0.93778
# 622/622 [==============================] - 261s 420ms/step - loss: 0.0358 - accuracy: 0.9886 - precision: 0.9862 - recall: 0.9898 - auc: 0.9990 - false_positives: 41.0000 - false_negatives: 30.0000 - true_negatives: 3223.0000 - f1_score: 0.6442 - val_loss: 0.6240 - val_accuracy: 0.8804 - val_precision: 0.8606 - val_recall: 0.8889 - val_auc: 0.9173 - val_false_positives: 105.0000 - val_false_negatives: 81.0000 - val_true_negatives: 721.0000 - val_f1_score: 0.6384
# Epoch 6/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9921 - precision: 0.9922 - recall: 0.9912 - auc: 0.9987 - false_positives: 23.0000 - false_negatives: 26.0000 - true_negatives: 3241.0000 - f1_score: 0.6442
# Epoch 6: val_auc did not improve from 0.93778
# 622/622 [==============================] - 262s 421ms/step - loss: 0.0311 - accuracy: 0.9921 - precision: 0.9922 - recall: 0.9912 - auc: 0.9987 - false_positives: 23.0000 - false_negatives: 26.0000 - true_negatives: 3241.0000 - f1_score: 0.6442 - val_loss: 0.5693 - val_accuracy: 0.8804 - val_precision: 0.8787 - val_recall: 0.8642 - val_auc: 0.9224 - val_false_positives: 87.0000 - val_false_negatives: 99.0000 - val_true_negatives: 739.0000 - val_f1_score: 0.6384
# Epoch 7/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9915 - precision: 0.9902 - recall: 0.9919 - auc: 0.9986 - false_positives: 29.0000 - false_negatives: 24.0000 - true_negatives: 3235.0000 - f1_score: 0.6442
# Epoch 7: val_auc did not improve from 0.93778
# 622/622 [==============================] - 262s 421ms/step - loss: 0.0291 - accuracy: 0.9915 - precision: 0.9902 - recall: 0.9919 - auc: 0.9986 - false_positives: 29.0000 - false_negatives: 24.0000 - true_negatives: 3235.0000 - f1_score: 0.6442 - val_loss: 0.5852 - val_accuracy: 0.8881 - val_precision: 0.8838 - val_recall: 0.8765 - val_auc: 0.9192 - val_false_positives: 84.0000 - val_false_negatives: 90.0000 - val_true_negatives: 742.0000 - val_f1_score: 0.6384
# Epoch 8/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9915 - precision: 0.9922 - recall: 0.9898 - auc: 0.9991 - false_positives: 23.0000 - false_negatives: 30.0000 - true_negatives: 3241.0000 - f1_score: 0.6442
# Epoch 8: val_auc did not improve from 0.93778
# 622/622 [==============================] - 262s 421ms/step - loss: 0.0232 - accuracy: 0.9915 - precision: 0.9922 - recall: 0.9898 - auc: 0.9991 - false_positives: 23.0000 - false_negatives: 30.0000 - true_negatives: 3241.0000 - f1_score: 0.6442 - val_loss: 0.6445 - val_accuracy: 0.8695 - val_precision: 0.8973 - val_recall: 0.8148 - val_auc: 0.9173 - val_false_positives: 68.0000 - val_false_negatives: 135.0000 - val_true_negatives: 758.0000 - val_f1_score: 0.6384
# Epoch 9/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9902 - auc: 0.9991 - false_positives: 26.0000 - false_negatives: 29.0000 - true_negatives: 3238.0000 - f1_score: 0.6442
# Epoch 9: val_auc did not improve from 0.93778
# 622/622 [==============================] - 262s 421ms/step - loss: 0.0260 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9902 - auc: 0.9991 - false_positives: 26.0000 - false_negatives: 29.0000 - true_negatives: 3238.0000 - f1_score: 0.6442 - val_loss: 0.5809 - val_accuracy: 0.8830 - val_precision: 0.8970 - val_recall: 0.8477 - val_auc: 0.9229 - val_false_positives: 71.0000 - val_false_negatives: 111.0000 - val_true_negatives: 755.0000 - val_f1_score: 0.6384
# Epoch 10/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9960 - precision: 0.9963 - recall: 0.9953 - auc: 0.9992 - false_positives: 11.0000 - false_negatives: 14.0000 - true_negatives: 3253.0000 - f1_score: 0.6442
# Epoch 10: val_auc did not improve from 0.93778
# 622/622 [==============================] - 262s 421ms/step - loss: 0.0153 - accuracy: 0.9960 - precision: 0.9963 - recall: 0.9953 - auc: 0.9992 - false_positives: 11.0000 - false_negatives: 14.0000 - true_negatives: 3253.0000 - f1_score: 0.6442 - val_loss: 0.6598 - val_accuracy: 0.8836 - val_precision: 0.8486 - val_recall: 0.9150 - val_auc: 0.9160 - val_false_positives: 119.0000 - val_false_negatives: 62.0000 - val_true_negatives: 707.0000 - val_f1_score: 0.6384
# Epoch 11/11
# 622/622 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9950 - precision: 0.9953 - recall: 0.9942 - auc: 0.9996 - false_positives: 14.0000 - false_negatives: 17.0000 - true_negatives: 3250.0000 - f1_score: 0.6442
# Epoch 11: val_auc did not improve from 0.93778
# 622/622 [==============================] - 262s 421ms/step - loss: 0.0153 - accuracy: 0.9950 - precision: 0.9953 - recall: 0.9942 - auc: 0.9996 - false_positives: 14.0000 - false_negatives: 17.0000 - true_negatives: 3250.0000 - f1_score: 0.6442 - val_loss: 0.5527 - val_accuracy: 0.8855 - val_precision: 0.8564 - val_recall: 0.9081 - val_auc: 0.9267 - val_false_positives: 111.0000 - val_false_negatives: 67.0000 - val_true_negatives: 715.0000 - val_f1_score: 0.6384

# %%
history_double_model.history
# Out:
# {'loss': [0.47601643204689026,
#   0.34810641407966614,
#   0.191011443734169,
#   0.07100605964660645,
#   0.035788677632808685,
#   0.031092990189790726,
#   0.02907160483300686,
#   0.023157820105552673,
#   0.02602933533489704,
#   0.015282640233635902,
#   0.015292542986571789],
#  'accuracy': [0.8030229806900024,
#   0.8610709309577942,
#   0.9276410937309265,
#   0.9760411381721497,
#   0.9885833859443665,
#   0.9921209216117859,
#   0.9914777278900146,
#   0.9914777278900146,
#   0.9911561608314514,
#   0.9959800839424133,
#   0.9950152635574341],
#  'precision': [0.8150036334991455,
#   0.8649214506149292,
#   0.9232848882675171,
#   0.9733468294143677,
#   0.9861766695976257,
#   0.9922086596488953,
#   0.9902027249336243,
#   0.99219810962677,
#   0.9911924004554749,
#   0.9962736964225769,
#   0.9952574372291565],
#  'recall': [0.7573603987693787,
#   0.8385787010192871,
#   0.9245346784591675,
#   0.9763113260269165,
#   0.989847719669342,
#   0.9912013411521912,
#   0.9918781518936157,
#   0.989847719669342,
#   0.9901861548423767,
#   0.9952622652053833,
#   0.9942470192909241],
#  'auc': [0.8453723788261414,
#   0.9227809906005859,
#   0.9769200086593628,
#   0.996346652507782,
#   0.9989666938781738,
#   0.998650074005127,
#   0.9985820651054382,
#   0.999065101146698,
#   0.9991161823272705,
#   0.9992344379425049,
#   0.9995611310005188],
#  'false_positives': [508.0,
#   387.0,
#   227.0,
#   79.0,
#   41.0,
#   23.0,
#   29.0,
#   23.0,
#   26.0,
#   11.0,
#   14.0],
#  'false_negatives': [717.0,
#   477.0,
#   223.0,
#   70.0,
#   30.0,
#   26.0,
#   24.0,
#   30.0,
#   29.0,
#   14.0,
#   17.0],
#  'true_negatives': [2756.0,
#   2877.0,
#   3037.0,
#   3185.0,
#   3223.0,
#   3241.0,
#   3235.0,
#   3241.0,
#   3238.0,
#   3253.0,
#   3250.0],
#  'f1_score': [0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935],
#  'val_loss': [0.42329663038253784,
#   0.37569659948349,
#   0.38098400831222534,
#   0.4776596128940582,
#   0.6240078806877136,
#   0.5692514181137085,
#   0.5852000713348389,
#   0.6444886922836304,
#   0.5808776617050171,
#   0.6597729921340942,
#   0.5527477264404297],
#  'val_accuracy': [0.8392282724380493,
#   0.8572347164154053,
#   0.8604501485824585,
#   0.8874598145484924,
#   0.8803858757019043,
#   0.8803858757019043,
#   0.8881028890609741,
#   0.8694533705711365,
#   0.882958173751831,
#   0.8836013078689575,
#   0.8855305314064026],
#  'val_precision': [0.8537666201591492,
#   0.8357616066932678,
#   0.8040379881858826,
#   0.876358687877655,
#   0.8605577945709229,
#   0.8786610960960388,
#   0.8838174343109131,
#   0.8972809910774231,
#   0.8969520926475525,
#   0.8486005067825317,
#   0.856403648853302],
#  'val_recall': [0.7928669452667236,
#   0.8655692934989929,
#   0.9286693930625916,
#   0.8847736716270447,
#   0.8888888955116272,
#   0.8641975522041321,
#   0.8765432238578796,
#   0.8148148059844971,
#   0.8477365970611572,
#   0.9149519801139832,
#   0.908093273639679],
#  'val_auc': [0.8942148089408875,
#   0.9292613863945007,
#   0.9377792477607727,
#   0.9341979026794434,
#   0.917286217212677,
#   0.9224218130111694,
#   0.9191684126853943,
#   0.9172760844230652,
#   0.9228901267051697,
#   0.9159591794013977,
#   0.9267388582229614],
#  'val_false_positives': [99.0,
#   124.0,
#   165.0,
#   91.0,
#   105.0,
#   87.0,
#   84.0,
#   68.0,
#   71.0,
#   119.0,
#   111.0],
#  'val_false_negatives': [151.0,
#   98.0,
#   52.0,
#   84.0,
#   81.0,
#   99.0,
#   90.0,
#   135.0,
#   111.0,
#   62.0,
#   67.0],
#  'val_true_negatives': [727.0,
#   702.0,
#   661.0,
#   735.0,
#   721.0,
#   739.0,
#   742.0,
#   758.0,
#   755.0,
#   707.0,
#   715.0],
#  'val_f1_score': [0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337]}

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 15), sharex=(True, True, False), sharey='row')

# Plot training & validation loss values
axes[0, 0].plot(history_double_model.history['loss'])
axes[0, 0].plot(history_double_model.history['val_loss'], linestyle='dashed')
axes[0, 0].set_title('Model Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend(['Train', 'Validation'], loc='upper left')
axes[0, 0].grid(True)

# Plot training & validation accuracy values
axes[0, 1].plot(history_double_model.history['accuracy'])
axes[0, 1].plot(history_double_model.history['val_accuracy'], linestyle='dashed')
axes[0, 1].set_title('Model accuracy')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend(['Train', 'Validation'], loc='upper left')
axes[0, 1].grid(True)

# Plot training & validation precision values
axes[0, 2].plot(history_double_model.history['precision'])
axes[0, 2].plot(history_double_model.history['val_precision'], linestyle='dashed')
axes[0, 2].set_title('Model precision')
axes[0, 2].set_xlabel('Epoch')
axes[0, 2].set_ylabel('Precision')
axes[0, 2].legend(['Train', 'Validation'], loc='upper left')
axes[0, 2].grid(True)

# Plot training & validation recall values
axes[1, 0].plot(history_double_model.history['recall'])
axes[1, 0].plot(history_double_model.history['val_recall'], linestyle='dashed')
axes[1, 0].set_title('Model recall')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].legend(['Train', 'Validation'], loc='upper left')
axes[1, 0].grid(True)

# Plot training & validation auc values
axes[1, 1].plot(history_double_model.history['auc'])
axes[1, 1].plot(history_double_model.history['val_auc'], linestyle='dashed')
axes[1, 1].set_title('Model AUC')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('AUC')
axes[1, 1].legend(['Train', 'Validation'], loc='upper left')
axes[1, 1].grid(True)

# Plot training & validation f1_score values
axes[1, 2].plot(history_double_model.history['f1_score'])
axes[1, 2].plot(history_double_model.history['val_f1_score'], linestyle='dashed')
axes[1, 2].set_title('Model F1 Score')
axes[1, 2].set_xlabel('Epoch')
axes[1, 2].set_ylabel('F1 Score')
axes[1, 2].legend(['Train', 'Validation'], loc='upper left')
axes[1, 2].grid(True)

# Plot training & validation true negatives values
axes[2, 0].plot(history_double_model.history['true_negatives'])
axes[2, 0].plot(history_double_model.history['val_true_negatives'], linestyle='dashed')
axes[2, 0].set_title('Model True Negatives')
axes[2, 0].set_xlabel('Epoch')
axes[2, 0].set_ylabel('True Negatives')
axes[2, 0].legend(['Train', 'Validation'], loc='upper left')
axes[2, 0].grid(True)

# Plot training & validation false positives values
axes[2, 1].plot(history_double_model.history['false_positives'])
axes[2, 1].plot(history_double_model.history['val_false_positives'], linestyle='dashed')
axes[2, 1].set_title('Model False Positives')
axes[2, 1].set_xlabel('Epoch')
axes[2, 1].set_ylabel('False Positives')
axes[2, 1].legend(['Train', 'Validation'], loc='upper left')
axes[2, 1].grid(True)

# Plot training & validation false negatives values
axes[2, 2].plot(history_double_model.history['false_negatives'])
axes[2, 2].plot(history_double_model.history['val_false_negatives'], linestyle='dashed')
axes[2, 2].set_title('Model False Negatives')
axes[2, 2].set_xlabel('Epoch')
axes[2, 2].set_ylabel('False Negatives')
axes[2, 2].legend(['Train', 'Validation'], loc='upper left')
axes[2, 2].grid(True)

plt.suptitle('Training and Validation Metrics over 11 Epochs for DoubleBERTClassifier (ETS & Claim)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluate

# %%
double_model.load_weights(model_checkpoint_path + 'model_double_weights_03_0.3810.h5') #third epoch

# %%
evaluation_double_model = double_model.evaluate({'claim_input_ids': test_claim_input_ids, 'claim_attention_mask': test_claim_attention_mask,
                                                 'ets_input_ids': test_ets_input_ids, 'ets_attention_mask': test_ets_attention_mask},
                            y_test)

metrics_names = double_model.metrics_names

print('Metrics for the SimpleBERTClassifier (ETS) model with the lowest AUC loss')
for metric_name, metric_value in zip(metrics_names, evaluation_double_model):
    print(f"{metric_name}: {metric_value:.4f}")
# Out:
# Claim Input Shape:  (None, 115)
# Claim Attention Mask Shape:  (None, 115)
# ETS Input Shape:  (None, 115)
# ETS Attention Mask Shape:  (None, 115)
# Input Shape:  (None, None)
# Attention Mask Shape:  (None, None)
# Claim Input Shape:  (None, 115)
# Claim Attention Mask Shape:  (None, 115)
# ETS Input Shape:  (None, 115)
# ETS Attention Mask Shape:  (None, 115)
# Input Shape:  (None, None)
# Attention Mask Shape:  (None, None)
# 61/61 [==============================] - 29s 383ms/step - loss: 0.3620 - accuracy: 0.8647 - precision: 0.8124 - recall: 0.9387 - auc: 0.9408 - false_positives: 205.0000 - false_negatives: 58.0000 - true_negatives: 793.0000 - f1_score: 0.6547
# Metrics for the SimpleBERTClassifier (ETS) model with the lowest AUC loss
# loss: 0.3620
# accuracy: 0.8647
# precision: 0.8124
# recall: 0.9387
# auc: 0.9408
# false_positives: 205.0000
# false_negatives: 58.0000
# true_negatives: 793.0000
# f1_score: 0.6547

# %% [markdown]
# ## Prediction

# %%
# Using the model to make predictions on test data (only Claim as the user will do)
ets_input_ids_zeros = tf.zeros((test_claim_input_ids.shape[0], 512), dtype=tf.int32)
ets_attention_mask_zeros = tf.zeros((test_claim_attention_mask.shape[0], 512), dtype=tf.int32)

print(test_claim_input_ids.shape, test_claim_attention_mask.shape, ets_input_ids_zeros.shape, ets_attention_mask_zeros.shape)


predictions_double_model = double_model.predict({'claim_input_ids': test_claim_input_ids, 'claim_attention_mask': test_claim_attention_mask,
                                                 'ets_input_ids': ets_input_ids_zeros, 'ets_attention_mask': ets_attention_mask_zeros})

predicted_labels = np.round(predictions_double_model)
# Out:
# (1944, 512) (1944, 512) (1944, 512) (1944, 512)
# Claim Input Shape:  (None, 115)
# Claim Attention Mask Shape:  (None, 115)
# ETS Input Shape:  (None, 115)
# ETS Attention Mask Shape:  (None, 115)
# Input Shape:  (None, None)
# Attention Mask Shape:  (None, None)
# 61/61 [==============================] - 8s 87ms/step

# %%
print(f'Predicted labels: {predictions_double_model}')
print(f'Rounded predicted labels: {predicted_labels}')

accuracy_double_model = accuracy_score(y_test, predicted_labels)
print(f'Accuracy: {accuracy_double_model:.4f}')
print()

auc_double_model = roc_auc_score(y_test, predictions_double_model)
print(f'AUC: {auc_double_model:.4f}')
print()

precision_double_model = precision_score(y_test, predicted_labels)
print(f'Precision: {precision_double_model:.4f}')
print()

recall_double_model = recall_score(y_test, predicted_labels)
print(f'Recall: {recall_double_model:.4f}')
print()

# Generate a confusion matrix
conf_mat_double_model = confusion_matrix(y_test, predicted_labels)
print('Confusion Matrix:')
print(conf_mat_double_model)
# Out:
# Predicted labels: [[0.7853272 ]
#  [0.9455252 ]
#  [0.05099987]
#  ...
#  [0.99285924]
#  [0.82356936]
#  [0.5638263 ]]
# Rounded predicted labels: [[1.]
#  [1.]
#  [0.]
#  ...
#  [1.]
#  [1.]
#  [1.]]
# Accuracy: 0.8297
#
# AUC: 0.9174
#
# Precision: 0.7700
#
# Recall: 0.9271
#
# Confusion Matrix:
# [[736 262]
#  [ 69 877]]

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat_double_model, display_labels=['FAKE', 'TRUE'])
disp.plot()
plt.show()

# %%
double_model.save_weights("/content/drive/MyDrive/Colab Notebooks/TB/final_weights/DoubleBERTClassifier_weights", save_format="tf")

# %%
#double_model.save("DoubleBERTClassifier", save_format="tf")

# %% [markdown]
# # DoubleBERTClassifier (Frozen BERT)
#
# This model allows us to compare the performance of the Double-Input architectur (the best one out of the three previous model) when BERT's pre-trained parameters are not fine-tuned. Only the parameters in the dense classification layer are trained. This will show us how powerful BERT could be.

# %% [markdown]
# ## Training

# %%
history_double_frz_model = double_model_frozen.fit(
    {'claim_input_ids': train_claim_input_ids,
    'claim_attention_mask': train_claim_attention_mask,
    'ets_input_ids': train_ets_input_ids,
    'ets_attention_mask': train_ets_attention_mask},
    y_train,
    epochs=num_epochs,
     validation_data=({'claim_input_ids': val_claim_input_ids, 'claim_attention_mask': val_claim_attention_mask,
                       'ets_input_ids': val_ets_input_ids, 'ets_attention_mask': val_ets_attention_mask}, y_val),
    batch_size=batch_size,
    callbacks=[model_checkpoint_double_frz]
)
# Out:
# Epoch 1/11
# Claim Input Shape:  (None, 115)
# Claim Attention Mask Shape:  (None, 115)
# ETS Input Shape:  (None, 115)
# ETS Attention Mask Shape:  (None, 115)
# Input Shape:  (None, None)
# Attention Mask Shape:  (None, None)
# Claim Input Shape:  (None, 115)
# Claim Attention Mask Shape:  (None, 115)
# ETS Input Shape:  (None, 115)
# ETS Attention Mask Shape:  (None, 115)
# Input Shape:  (None, None)
# Attention Mask Shape:  (None, None)
# 622/622 [==============================] - ETA: 0s - loss: 0.6024 - accuracy: 0.6982 - precision: 0.7207 - recall: 0.5956 - auc: 0.7499 - false_positives: 682.0000 - false_negatives: 1195.0000 - true_negatives: 2582.0000 - f1_score: 0.6442Claim Input Shape:  (None, 115)
# Claim Attention Mask Shape:  (None, 115)
# ETS Input Shape:  (None, 115)
# ETS Attention Mask Shape:  (None, 115)
# Input Shape:  (None, None)
# Attention Mask Shape:  (None, None)
#
# Epoch 1: val_auc improved from -inf to 0.78633, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_double_frz_weights_01_0.5637.h5
# 622/622 [==============================] - 136s 194ms/step - loss: 0.6024 - accuracy: 0.6982 - precision: 0.7207 - recall: 0.5956 - auc: 0.7499 - false_positives: 682.0000 - false_negatives: 1195.0000 - true_negatives: 2582.0000 - f1_score: 0.6442 - val_loss: 0.5637 - val_accuracy: 0.7524 - val_precision: 0.7493 - val_recall: 0.7092 - val_auc: 0.7863 - val_false_positives: 173.0000 - val_false_negatives: 212.0000 - val_true_negatives: 653.0000 - val_f1_score: 0.6384
# Epoch 2/11
# 622/622 [==============================] - ETA: 0s - loss: 0.5670 - accuracy: 0.7408 - precision: 0.7436 - recall: 0.6937 - auc: 0.7833 - false_positives: 707.0000 - false_negatives: 905.0000 - true_negatives: 2557.0000 - f1_score: 0.6442
# Epoch 2: val_auc improved from 0.78633 to 0.79356, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_double_frz_weights_02_0.5564.h5
# 622/622 [==============================] - 118s 189ms/step - loss: 0.5670 - accuracy: 0.7408 - precision: 0.7436 - recall: 0.6937 - auc: 0.7833 - false_positives: 707.0000 - false_negatives: 905.0000 - true_negatives: 2557.0000 - f1_score: 0.6442 - val_loss: 0.5564 - val_accuracy: 0.7492 - val_precision: 0.7747 - val_recall: 0.6557 - val_auc: 0.7936 - val_false_positives: 139.0000 - val_false_negatives: 251.0000 - val_true_negatives: 687.0000 - val_f1_score: 0.6384
# Epoch 3/11
# 622/622 [==============================] - ETA: 0s - loss: 0.5535 - accuracy: 0.7538 - precision: 0.7532 - recall: 0.7168 - auc: 0.7928 - false_positives: 694.0000 - false_negatives: 837.0000 - true_negatives: 2570.0000 - f1_score: 0.6442
# Epoch 3: val_auc improved from 0.79356 to 0.79864, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_double_frz_weights_03_0.5473.h5
# 622/622 [==============================] - 117s 189ms/step - loss: 0.5535 - accuracy: 0.7538 - precision: 0.7532 - recall: 0.7168 - auc: 0.7928 - false_positives: 694.0000 - false_negatives: 837.0000 - true_negatives: 2570.0000 - f1_score: 0.6442 - val_loss: 0.5473 - val_accuracy: 0.7601 - val_precision: 0.7834 - val_recall: 0.6749 - val_auc: 0.7986 - val_false_positives: 136.0000 - val_false_negatives: 237.0000 - val_true_negatives: 690.0000 - val_f1_score: 0.6384
# Epoch 4/11
# 622/622 [==============================] - ETA: 0s - loss: 0.5484 - accuracy: 0.7641 - precision: 0.7648 - recall: 0.7272 - auc: 0.7952 - false_positives: 661.0000 - false_negatives: 806.0000 - true_negatives: 2603.0000 - f1_score: 0.6442
# Epoch 4: val_auc improved from 0.79864 to 0.80565, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_double_frz_weights_04_0.5349.h5
# 622/622 [==============================] - 117s 189ms/step - loss: 0.5484 - accuracy: 0.7641 - precision: 0.7648 - recall: 0.7272 - auc: 0.7952 - false_positives: 661.0000 - false_negatives: 806.0000 - true_negatives: 2603.0000 - f1_score: 0.6442 - val_loss: 0.5349 - val_accuracy: 0.7736 - val_precision: 0.7728 - val_recall: 0.7325 - val_auc: 0.8056 - val_false_positives: 157.0000 - val_false_negatives: 195.0000 - val_true_negatives: 669.0000 - val_f1_score: 0.6384
# Epoch 5/11
# 622/622 [==============================] - ETA: 0s - loss: 0.5399 - accuracy: 0.7728 - precision: 0.7705 - recall: 0.7431 - auc: 0.8013 - false_positives: 654.0000 - false_negatives: 759.0000 - true_negatives: 2610.0000 - f1_score: 0.6442
# Epoch 5: val_auc did not improve from 0.80565
# 622/622 [==============================] - 116s 187ms/step - loss: 0.5399 - accuracy: 0.7728 - precision: 0.7705 - recall: 0.7431 - auc: 0.8013 - false_positives: 654.0000 - false_negatives: 759.0000 - true_negatives: 2610.0000 - f1_score: 0.6442 - val_loss: 0.5312 - val_accuracy: 0.7672 - val_precision: 0.7595 - val_recall: 0.7366 - val_auc: 0.8046 - val_false_positives: 170.0000 - val_false_negatives: 192.0000 - val_true_negatives: 656.0000 - val_f1_score: 0.6384
# Epoch 6/11
# 622/622 [==============================] - ETA: 0s - loss: 0.5357 - accuracy: 0.7768 - precision: 0.7781 - recall: 0.7418 - auc: 0.8042 - false_positives: 625.0000 - false_negatives: 763.0000 - true_negatives: 2639.0000 - f1_score: 0.6442
# Epoch 6: val_auc did not improve from 0.80565
# 622/622 [==============================] - 116s 187ms/step - loss: 0.5357 - accuracy: 0.7768 - precision: 0.7781 - recall: 0.7418 - auc: 0.8042 - false_positives: 625.0000 - false_negatives: 763.0000 - true_negatives: 2639.0000 - f1_score: 0.6442 - val_loss: 0.5291 - val_accuracy: 0.7685 - val_precision: 0.7610 - val_recall: 0.7380 - val_auc: 0.8043 - val_false_positives: 169.0000 - val_false_negatives: 191.0000 - val_true_negatives: 657.0000 - val_f1_score: 0.6384
# Epoch 7/11
# 622/622 [==============================] - ETA: 0s - loss: 0.5368 - accuracy: 0.7731 - precision: 0.7705 - recall: 0.7442 - auc: 0.8011 - false_positives: 655.0000 - false_negatives: 756.0000 - true_negatives: 2609.0000 - f1_score: 0.6442
# Epoch 7: val_auc improved from 0.80565 to 0.81062, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_double_frz_weights_07_0.5285.h5
# 622/622 [==============================] - 117s 189ms/step - loss: 0.5368 - accuracy: 0.7731 - precision: 0.7705 - recall: 0.7442 - auc: 0.8011 - false_positives: 655.0000 - false_negatives: 756.0000 - true_negatives: 2609.0000 - f1_score: 0.6442 - val_loss: 0.5285 - val_accuracy: 0.7736 - val_precision: 0.7458 - val_recall: 0.7846 - val_auc: 0.8106 - val_false_positives: 195.0000 - val_false_negatives: 157.0000 - val_true_negatives: 631.0000 - val_f1_score: 0.6384
# Epoch 8/11
# 622/622 [==============================] - ETA: 0s - loss: 0.5279 - accuracy: 0.7768 - precision: 0.7721 - recall: 0.7523 - auc: 0.8099 - false_positives: 656.0000 - false_negatives: 732.0000 - true_negatives: 2608.0000 - f1_score: 0.6442
# Epoch 8: val_auc did not improve from 0.81062
# 622/622 [==============================] - 116s 187ms/step - loss: 0.5279 - accuracy: 0.7768 - precision: 0.7721 - recall: 0.7523 - auc: 0.8099 - false_positives: 656.0000 - false_negatives: 732.0000 - true_negatives: 2608.0000 - f1_score: 0.6442 - val_loss: 0.5314 - val_accuracy: 0.7730 - val_precision: 0.7423 - val_recall: 0.7901 - val_auc: 0.8081 - val_false_positives: 200.0000 - val_false_negatives: 153.0000 - val_true_negatives: 626.0000 - val_f1_score: 0.6384
# Epoch 9/11
# 622/622 [==============================] - ETA: 0s - loss: 0.5263 - accuracy: 0.7771 - precision: 0.7702 - recall: 0.7567 - auc: 0.8100 - false_positives: 667.0000 - false_negatives: 719.0000 - true_negatives: 2597.0000 - f1_score: 0.6442
# Epoch 9: val_auc improved from 0.81062 to 0.81073, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_double_frz_weights_09_0.5243.h5
# 622/622 [==============================] - 117s 189ms/step - loss: 0.5263 - accuracy: 0.7771 - precision: 0.7702 - recall: 0.7567 - auc: 0.8100 - false_positives: 667.0000 - false_negatives: 719.0000 - true_negatives: 2597.0000 - f1_score: 0.6442 - val_loss: 0.5243 - val_accuracy: 0.7781 - val_precision: 0.7540 - val_recall: 0.7819 - val_auc: 0.8107 - val_false_positives: 186.0000 - val_false_negatives: 159.0000 - val_true_negatives: 640.0000 - val_f1_score: 0.6384
# Epoch 10/11
# 622/622 [==============================] - ETA: 0s - loss: 0.5235 - accuracy: 0.7797 - precision: 0.7728 - recall: 0.7597 - auc: 0.8118 - false_positives: 660.0000 - false_negatives: 710.0000 - true_negatives: 2604.0000 - f1_score: 0.6442
# Epoch 10: val_auc improved from 0.81073 to 0.81110, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_double_frz_weights_10_0.5255.h5
# 622/622 [==============================] - 117s 189ms/step - loss: 0.5235 - accuracy: 0.7797 - precision: 0.7728 - recall: 0.7597 - auc: 0.8118 - false_positives: 660.0000 - false_negatives: 710.0000 - true_negatives: 2604.0000 - f1_score: 0.6442 - val_loss: 0.5255 - val_accuracy: 0.7781 - val_precision: 0.7883 - val_recall: 0.7202 - val_auc: 0.8111 - val_false_positives: 141.0000 - val_false_negatives: 204.0000 - val_true_negatives: 685.0000 - val_f1_score: 0.6384
# Epoch 11/11
# 622/622 [==============================] - ETA: 0s - loss: 0.5242 - accuracy: 0.7804 - precision: 0.7748 - recall: 0.7580 - auc: 0.8114 - false_positives: 651.0000 - false_negatives: 715.0000 - true_negatives: 2613.0000 - f1_score: 0.6442
# Epoch 11: val_auc improved from 0.81110 to 0.81115, saving model to /content/drive/MyDrive/Colab Notebooks/TB/model_checkpoints/model_double_frz_weights_11_0.5194.h5
# 622/622 [==============================] - 117s 189ms/step - loss: 0.5242 - accuracy: 0.7804 - precision: 0.7748 - recall: 0.7580 - auc: 0.8114 - false_positives: 651.0000 - false_negatives: 715.0000 - true_negatives: 2613.0000 - f1_score: 0.6442 - val_loss: 0.5194 - val_accuracy: 0.7820 - val_precision: 0.7762 - val_recall: 0.7517 - val_auc: 0.8112 - val_false_positives: 158.0000 - val_false_negatives: 181.0000 - val_true_negatives: 668.0000 - val_f1_score: 0.6384

# %%
history_double_frz_model.history
# Out:
# {'loss': [0.6023692488670349,
#   0.5670442581176758,
#   0.5535233020782471,
#   0.5483733415603638,
#   0.5399104356765747,
#   0.5357366800308228,
#   0.5368159413337708,
#   0.5278997421264648,
#   0.5263205766677856,
#   0.523543655872345,
#   0.5241754055023193],
#  'accuracy': [0.698183000087738,
#   0.7407943606376648,
#   0.753818929195404,
#   0.7641099691390991,
#   0.7727930545806885,
#   0.7768129706382751,
#   0.7731146216392517,
#   0.7768129706382751,
#   0.7771345973014832,
#   0.7797073721885681,
#   0.7803505659103394],
#  'precision': [0.7207207083702087,
#   0.743561863899231,
#   0.7532005906105042,
#   0.764768660068512,
#   0.7705262899398804,
#   0.7781327366828918,
#   0.7704975605010986,
#   0.7721431255340576,
#   0.7702376842498779,
#   0.7728055119514465,
#   0.7748184204101562],
#  'recall': [0.5956006646156311,
#   0.6937394142150879,
#   0.7167512774467468,
#   0.7272419333457947,
#   0.7431471943855286,
#   0.7417935729026794,
#   0.7441624402999878,
#   0.7522842884063721,
#   0.7566835880279541,
#   0.759729266166687,
#   0.7580372095108032],
#  'auc': [0.7499210238456726,
#   0.7833430171012878,
#   0.7927688956260681,
#   0.7952455878257751,
#   0.8013371229171753,
#   0.80418860912323,
#   0.8011077642440796,
#   0.8099205493927002,
#   0.810035228729248,
#   0.8118131160736084,
#   0.8113773465156555],
#  'false_positives': [682.0,
#   707.0,
#   694.0,
#   661.0,
#   654.0,
#   625.0,
#   655.0,
#   656.0,
#   667.0,
#   660.0,
#   651.0],
#  'false_negatives': [1195.0,
#   905.0,
#   837.0,
#   806.0,
#   759.0,
#   763.0,
#   756.0,
#   732.0,
#   719.0,
#   710.0,
#   715.0],
#  'true_negatives': [2582.0,
#   2557.0,
#   2570.0,
#   2603.0,
#   2610.0,
#   2639.0,
#   2609.0,
#   2608.0,
#   2597.0,
#   2604.0,
#   2613.0],
#  'f1_score': [0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935,
#   0.6442118883132935],
#  'val_loss': [0.5637248158454895,
#   0.5563571453094482,
#   0.5472506284713745,
#   0.5349061489105225,
#   0.5311843156814575,
#   0.5291441679000854,
#   0.5285352468490601,
#   0.5313627123832703,
#   0.5242762565612793,
#   0.5255212187767029,
#   0.519418478012085],
#  'val_accuracy': [0.7524116039276123,
#   0.7491961121559143,
#   0.7601286172866821,
#   0.7736334204673767,
#   0.7672025561332703,
#   0.7684887647628784,
#   0.7736334204673767,
#   0.772990345954895,
#   0.7781350612640381,
#   0.7781350612640381,
#   0.781993567943573],
#  'val_precision': [0.7492753863334656,
#   0.7747163772583008,
#   0.7834395170211792,
#   0.7727930545806885,
#   0.7595474123954773,
#   0.7609618306159973,
#   0.7457627058029175,
#   0.7422680258750916,
#   0.7539682388305664,
#   0.7882882952690125,
#   0.776203989982605],
#  'val_recall': [0.7091906666755676,
#   0.6556927561759949,
#   0.6748971343040466,
#   0.7325102686882019,
#   0.7366254925727844,
#   0.7379972338676453,
#   0.7846364974975586,
#   0.790123462677002,
#   0.7818930149078369,
#   0.7201645970344543,
#   0.7517147064208984],
#  'val_auc': [0.786327064037323,
#   0.7935578227043152,
#   0.7986437082290649,
#   0.8056485652923584,
#   0.804620623588562,
#   0.8042585253715515,
#   0.8106215596199036,
#   0.8080657720565796,
#   0.8107286691665649,
#   0.811095654964447,
#   0.811153769493103],
#  'val_false_positives': [173.0,
#   139.0,
#   136.0,
#   157.0,
#   170.0,
#   169.0,
#   195.0,
#   200.0,
#   186.0,
#   141.0,
#   158.0],
#  'val_false_negatives': [212.0,
#   251.0,
#   237.0,
#   195.0,
#   192.0,
#   191.0,
#   157.0,
#   153.0,
#   159.0,
#   204.0,
#   181.0],
#  'val_true_negatives': [653.0,
#   687.0,
#   690.0,
#   669.0,
#   656.0,
#   657.0,
#   631.0,
#   626.0,
#   640.0,
#   685.0,
#   668.0],
#  'val_f1_score': [0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337,
#   0.6383537650108337]}

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 15), sharex=(True, True, False), sharey='row')

# Plot training & validation loss values
axes[0, 0].plot(history_double_frz_model.history['loss'])
axes[0, 0].plot(history_double_frz_model.history['val_loss'], linestyle='dashed')
axes[0, 0].set_title('Model Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend(['Train', 'Validation'], loc='upper left')
axes[0, 0].grid(True)

# Plot training & validation accuracy values
axes[0, 1].plot(history_double_frz_model.history['accuracy'])
axes[0, 1].plot(history_double_frz_model.history['val_accuracy'], linestyle='dashed')
axes[0, 1].set_title('Model accuracy')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend(['Train', 'Validation'], loc='upper left')
axes[0, 1].grid(True)

# Plot training & validation precision values
axes[0, 2].plot(history_double_frz_model.history['precision'])
axes[0, 2].plot(history_double_frz_model.history['val_precision'], linestyle='dashed')
axes[0, 2].set_title('Model precision')
axes[0, 2].set_xlabel('Epoch')
axes[0, 2].set_ylabel('Precision')
axes[0, 2].legend(['Train', 'Validation'], loc='upper left')
axes[0, 2].grid(True)

# Plot training & validation recall values
axes[1, 0].plot(history_double_frz_model.history['recall'])
axes[1, 0].plot(history_double_frz_model.history['val_recall'], linestyle='dashed')
axes[1, 0].set_title('Model recall')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].legend(['Train', 'Validation'], loc='upper left')
axes[1, 0].grid(True)

# Plot training & validation auc values
axes[1, 1].plot(history_double_frz_model.history['auc'])
axes[1, 1].plot(history_double_frz_model.history['val_auc'], linestyle='dashed')
axes[1, 1].set_title('Model AUC')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('AUC')
axes[1, 1].legend(['Train', 'Validation'], loc='upper left')
axes[1, 1].grid(True)

# Plot training & validation f1_score values
axes[1, 2].plot(history_double_frz_model.history['f1_score'])
axes[1, 2].plot(history_double_frz_model.history['val_f1_score'], linestyle='dashed')
axes[1, 2].set_title('Model F1 Score')
axes[1, 2].set_xlabel('Epoch')
axes[1, 2].set_ylabel('F1 Score')
axes[1, 2].legend(['Train', 'Validation'], loc='upper left')
axes[1, 2].grid(True)

# Plot training & validation true negatives values
axes[2, 0].plot(history_double_frz_model.history['true_negatives'])
axes[2, 0].plot(history_double_frz_model.history['val_true_negatives'], linestyle='dashed')
axes[2, 0].set_title('Model True Negatives')
axes[2, 0].set_xlabel('Epoch')
axes[2, 0].set_ylabel('True Negatives')
axes[2, 0].legend(['Train', 'Validation'], loc='upper left')
axes[2, 0].grid(True)

# Plot training & validation false positives values
axes[2, 1].plot(history_double_frz_model.history['false_positives'])
axes[2, 1].plot(history_double_frz_model.history['val_false_positives'], linestyle='dashed')
axes[2, 1].set_title('Model False Positives')
axes[2, 1].set_xlabel('Epoch')
axes[2, 1].set_ylabel('False Positives')
axes[2, 1].legend(['Train', 'Validation'], loc='upper left')
axes[2, 1].grid(True)

# Plot training & validation false negatives values
axes[2, 2].plot(history_double_frz_model.history['false_negatives'])
axes[2, 2].plot(history_double_frz_model.history['val_false_negatives'], linestyle='dashed')
axes[2, 2].set_title('Model False Negatives')
axes[2, 2].set_xlabel('Epoch')
axes[2, 2].set_ylabel('False Negatives')
axes[2, 2].legend(['Train', 'Validation'], loc='upper left')
axes[2, 2].grid(True)

plt.suptitle('Training and Validation Metrics over 11 Epochs for DoubleBERTClassifier (Frozen BERT)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluate

# %%
double_model_frozen.load_weights(model_checkpoint_path + 'model_double_frz_weights_11_0.5194.h5') #11 EPOCH

# %%
evaluation_double_frz_model = double_model_frozen.evaluate({'claim_input_ids': test_claim_input_ids, 'claim_attention_mask': test_claim_attention_mask,
                                                 'ets_input_ids': test_ets_input_ids, 'ets_attention_mask': test_ets_attention_mask},
                            y_test)

metrics_names = double_model_frozen.metrics_names

print('Metrics for the SimpleBERTClassifier (ETS) model with the lowest AUC loss')
for metric_name, metric_value in zip(metrics_names, evaluation_double_frz_model):
    print(f"{metric_name}: {metric_value:.4f}")
# Out:
# 61/61 [==============================] - 23s 382ms/step - loss: 0.5328 - accuracy: 0.7762 - precision: 0.7768 - recall: 0.7579 - auc: 0.8009 - false_positives: 206.0000 - false_negatives: 229.0000 - true_negatives: 792.0000 - f1_score: 0.6547
# Metrics for the SimpleBERTClassifier (ETS) model with the lowest AUC loss
# loss: 0.5328
# accuracy: 0.7762
# precision: 0.7768
# recall: 0.7579
# auc: 0.8009
# false_positives: 206.0000
# false_negatives: 229.0000
# true_negatives: 792.0000
# f1_score: 0.6547

# %% [markdown]
# ## Prediction

# %%
# Using the model to make predictions on test data (only Claim as the user will do)
ets_input_ids_zeros = tf.zeros((test_claim_input_ids.shape[0], 512), dtype=tf.int32)
ets_attention_mask_zeros = tf.zeros((test_claim_attention_mask.shape[0], 512), dtype=tf.int32)

print(test_claim_input_ids.shape, test_claim_attention_mask.shape, ets_input_ids_zeros.shape, ets_attention_mask_zeros.shape)


predictions_double_frz_model = double_model_frozen.predict({'claim_input_ids': test_claim_input_ids, 'claim_attention_mask': test_claim_attention_mask,
                                                 'ets_input_ids': ets_input_ids_zeros, 'ets_attention_mask': ets_attention_mask_zeros})

predicted_labels = np.round(predictions_double_frz_model)
# Out:
# (1944, 512) (1944, 512) (1944, 512) (1944, 512)
# Claim Input Shape:  (None, 115)
# Claim Attention Mask Shape:  (None, 115)
# ETS Input Shape:  (None, 115)
# ETS Attention Mask Shape:  (None, 115)
# Input Shape:  (None, None)
# Attention Mask Shape:  (None, None)
# 61/61 [==============================] - 8s 89ms/step

# %%
print(f'Predicted labels: {predictions_double_frz_model}')
print(f'Rounded predicted labels: {predicted_labels}')

accuracy_double_frz_model = accuracy_score(y_test, predicted_labels)
print(f'Accuracy: {accuracy_double_frz_model:.4f}')
print()

auc_double_frz_model = roc_auc_score(y_test, predictions_double_frz_model)
print(f'AUC: {auc_double_frz_model:.4f}')
print()

precision_double_frz_model = precision_score(y_test, predicted_labels)
print(f'Precision: {precision_double_frz_model:.4f}')
print()

recall_double_frz_model = recall_score(y_test, predicted_labels)
print(f'Recall: {recall_double_frz_model:.4f}')
print()

# Generate a confusion matrix
conf_mat_double_frz_model = confusion_matrix(y_test, predicted_labels)
print('Confusion Matrix:')
print(conf_mat_double_frz_model)
# Out:
# Predicted labels: [[0.6519284 ]
#  [0.7386849 ]
#  [0.35575262]
#  ...
#  [0.72676384]
#  [0.8570646 ]
#  [0.8566507 ]]
# Rounded predicted labels: [[1.]
#  [1.]
#  [0.]
#  ...
#  [1.]
#  [1.]
#  [1.]]
# Accuracy: 0.5936
#
# AUC: 0.7421
#
# Precision: 0.5484
#
# Recall: 0.9345
#
# Confusion Matrix:
# [[270 728]
#  [ 62 884]]

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat_double_frz_model, display_labels=['FAKE', 'TRUE'])
disp.plot()
plt.show()

# %%
double_model_frozen.save_weights("/content/drive/MyDrive/Colab Notebooks/TB/final_weights/DoubleBERTClassifierFrozen_weights", save_format="tf")

# %% [markdown]
# # Model Comparison

# %%
model_names = ['SimpleBERTClassifier (Claim)', 'SimpleBERTClassifier (ETS)', 'DoubleBERTClassifier', 'DoubleBERTClassifier (frz)']
colors = ['blue', 'orange', 'green', 'red']

# %% [markdown]
# ## Training

# %%
histories = [history_model_claim, history_model_ets, history_double_model, history_double_frz_model]


fig, axes = plt.subplots(3, 3, figsize=(15, 15), sharex=(True, True, False), sharey='row')

for color, history, model_name in zip(colors, histories, model_names):
    # Plot training & validation loss values
    axes[0, 0].plot(history.history['loss'], label=f'{model_name} - Train', color=color)
    axes[0, 0].plot(history.history['val_loss'], label=f'{model_name} - Validation', color=color, linestyle='dashed')

    # Plot training & validation accuracy values
    axes[0, 1].plot(history.history['accuracy'], label=f'{model_name} - Train', color=color)
    axes[0, 1].plot(history.history['val_accuracy'], label=f'{model_name} - Validation', color=color, linestyle='dashed')

    # Plot training & validation precision values
    axes[0, 2].plot(history.history['precision'], label=f'{model_name} - Train', color=color)
    axes[0, 2].plot(history.history['val_precision'], label=f'{model_name} - Validation', color=color, linestyle='dashed')

    # Plot training & validation precision recall
    axes[1, 0].plot(history.history['recall'], label=f'{model_name} - Train', color=color)
    axes[1, 0].plot(history.history['val_recall'], label=f'{model_name} - Validation', color=color, linestyle='dashed')

    # Plot training & validation auc values
    axes[1, 1].plot(history.history['auc'], label=f'{model_name} - Train', color=color)
    axes[1, 1].plot(history.history['val_auc'], label=f'{model_name} - Validation', color=color, linestyle='dashed')

    # Plot training & validation F1 Score values
    axes[1, 2].plot(history.history['f1_score'], label=f'{model_name} - Train', color=color)
    axes[1, 2].plot(history.history['val_f1_score'], label=f'{model_name} - Validation', color=color, linestyle='dashed')

    # Plot training & validation auc true_negatives
    axes[2, 0].plot(history.history['true_negatives'], label=f'{model_name} - Train', color=color)
    axes[2, 0].plot(history.history['val_true_negatives'], label=f'{model_name} - Validation', color=color, linestyle='dashed')

    # Plot training & validation auc false_positives
    axes[2, 1].plot(history.history['false_positives'], label=f'{model_name} - Train', color=color)
    axes[2, 1].plot(history.history['val_false_positives'], label=f'{model_name} - Validation', color=color, linestyle='dashed')

     # Plot training & validation auc false_negatives
    axes[2, 2].plot(history.history['false_negatives'], label=f'{model_name} - Train', color=color)
    axes[2, 2].plot(history.history['val_false_negatives'], label=f'{model_name} - Validation', color=color, linestyle='dashed')


# Add legends to the plots
axes[0, 0].legend(loc='upper left')

# Set titles and labels
axes[0, 0].set_title('Models Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].grid(True)

axes[0, 1].set_title('Models Accuracy')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].grid(True)

axes[0, 2].set_title('Models Precision')
axes[0, 2].set_xlabel('Epoch')
axes[0, 2].set_ylabel('Loss')
axes[0, 2].grid(True)

axes[1, 0].set_title('Models Recall')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Precision')
axes[1, 0].grid(True)

axes[1, 1].set_title('Models AUC')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('AUC')
axes[1, 1].grid(True)

axes[1, 2].set_title('Models F1 Score')
axes[1, 2].set_xlabel('Epoch')
axes[1, 2].set_ylabel('F1 Score')
axes[1, 2].grid(True)

axes[2, 0].set_title('Models True Negatives')
axes[2, 0].set_xlabel('Epoch')
axes[2, 0].set_ylabel('True Negatives')
axes[2, 0].grid(True)

axes[2, 1].set_title('Models False Positives')
axes[2, 1].set_xlabel('Epoch')
axes[2, 1].set_ylabel('False Positives')
axes[2, 1].grid(True)

axes[2, 2].set_title('Models False Negatives')
axes[2, 2].set_xlabel('Epoch')
axes[2, 2].set_ylabel('False Negatives')
axes[2, 2].grid(True)

# Adjust layout
plt.suptitle('Training and Validation Metrics for the three Models', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluation
# Evaluation on the best weights (= highest AUC)

# %%
evaluations = [evaluation_model_claim, evaluation_model_ets, evaluation_double_model, evaluation_double_frz_model]

test_losses = [evaluation[0] for evaluation in evaluations]
test_accuracies = [evaluation[2] for evaluation in evaluations]
test_precisions = [evaluation[3] for evaluation in evaluations]
test_recall = [evaluation[4] for evaluation in evaluations]


fig, axes = plt.subplots(2, 2, figsize=(15, 5), sharex='all', sharey='all')

axes[0, 0].bar(model_names, test_losses, color=['blue', 'orange', 'green', 'red'])
axes[0, 0].set_title('Test Loss Comparaison')
axes[0, 0].set_ylabel('Loss')

axes[0, 1].bar(model_names, test_accuracies, color=['blue', 'orange', 'green', 'red'])
axes[0, 1].set_title('Test Accuracy Comparaison')
axes[0, 1].set_ylabel('Accuracy')

axes[1, 0].bar(model_names, test_precisions, color=['blue', 'orange', 'green', 'red'])
axes[1, 0].set_title('Test Precision Comparaison')
axes[1, 0].set_ylabel('Precision')

axes[1, 1].bar(model_names, test_recall, color=['blue', 'orange', 'green', 'red'])
axes[1, 1].set_title('Test Recall Comparaison')
axes[1, 1].set_ylabel('Recall')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Prediction

# %%
confusion_matrices = [conf_mat_model_claim, conf_mat_model_ets, conf_mat_double_model, conf_mat_double_frz_model]

fig, axes = plt.subplots(figsize=(10, 5))

labels = ['True Negative', 'False Positive', 'False Negative', 'True Positive']

for i, values in enumerate(confusion_matrices):
    model_name = model_names[i]
    axes.bar([f'{label}\n({model_name})' for label in labels], values.ravel(), alpha=0.7, width=0.5, label=f'{model_name}')

axes.set_xticks(axes.get_xticks())
axes.set_xticklabels([label.get_text() for label in axes.get_xticklabels()], rotation=45, ha='right')

axes.set_title('Confusion Matrix Comparison')
axes.set_ylabel('Counts')
axes.legend()

plt.tight_layout()
plt.show()

# %%
accuracies = [accuracy_model_claim, accuracy_model_ets, accuracy_double_model, accuracy_double_frz_model]
aucs = [auc_model_claim, auc_model_ets, auc_double_model , auc_double_frz_model]
precisions = [precision_model_claim, precision_model_ets, precision_double_model , precision_double_frz_model]
recalls = [recall_model_claim, recall_model_ets, recall_double_model, recall_double_frz_model]

metrics = ['Prediction Accuracy', 'Prediction AUC', 'Prediction Precision', 'Prediction Recall']
metric_values = [accuracies, aucs, precisions, recalls]

# Create a figure for metric comparison
fig, axes = plt.subplots(2, 2, figsize=(15, 10), sharex='all', sharey='all')

# Plot each metric comparison
for i, (metric, values) in enumerate(zip(metrics, metric_values)):
    ax = axes[i // 2, i % 2]  # Calculate subplot indices
    bars = ax.bar(model_names, values, color=['blue', 'orange', 'green', 'red'])
    ax.set_title(f'{metric} Comparison')
    ax.set_ylabel(metric)

    for bar in bars:
      height = bar.get_height()
      ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                  xytext=(0, 3), textcoords='offset points',
                  ha='center', va='bottom')

# Adjust layout
plt.tight_layout()
plt.show()
